# %%
from nltk import WordPunctTokenizer
from tqdm import tqdm
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import numpy as np
import pickle as pkl
# Out:
# c:\users\1\appdata\local\programs\python\python36\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
tokenizer = WordPunctTokenizer()

# %%
def acquire_documents(filename):
    with open(filename+'.txt','r',encoding='utf-8') as l:
        lemmas = l.read().split('\n')
    l.close()
    tokens = tokenizer.tokenize_sents(lemmas)
    documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(tokens)]
    return lemmas, tokens, documents

# %%
train_texts, train_tokens, train_documents = acquire_documents('Train_lemmas')

# %%
dim = 300

# %%
model = Doc2Vec(train_documents, vector_size=dim, window=2, min_count=1, workers=4)

# %%
model.save('Train_only.model')

# %%
train_vectors = [model.infer_vector(i.words) for i in tqdm(train_documents)]
# Out:
# 100%|███████████████████████████████████| 87844/87844 [02:20<00:00, 624.09it/s]

# %%
with open('Train_{}.pkl'.format(dim), 'wb') as tw001:
    pkl.dump(np.array(train_vectors), tw001)

# %%
test_texts, test_tokens, test_documents = acquire_documents('Test_lemmas')

# %%
test_vectors = [model.infer_vector(i.words) for i in tqdm(test_documents)]
# Out:
# 100%|█████████████████████████████████████| 1000/1000 [00:04<00:00, 210.24it/s]

# %%
with open('Test_{}.pkl'.format(dim), 'wb') as tw002:
    pkl.dump(np.array(test_vectors), tw002)

# %%
val_texts, val_tokens, val_documents = acquire_documents('Val_lemmas')

# %%
val_vectors = [model.infer_vector(i.words) for i in tqdm(val_documents)]
# Out:
# 100%|█████████████████████████████████████| 1000/1000 [00:01<00:00, 631.02it/s]

# %%
with open('Val_{}.pkl'.format(dim), 'wb') as tw003:
    pkl.dump(np.array(val_vectors), tw003)

# %%
with open('top_threehundred_sorted_cutathundred.pkl', 'rb') as t:
    top_word_sets = {k:set(val[:300]) for k, val in (pkl.load(t)).items()}
t.close()

# %%
top_word_sets['anime']
# Out:
# {'акир',
#  'алхимик',
#  'аниме',
#  'анимешка',
#  'анимешник',
#  'анимешный',
#  'анимэ',
#  'арка',
#  'арт',
#  'бибоп',
#  'блич',
#  'боевой',
#  'вампир',
#  'википедия',
#  'волос',
#  'героиня',
#  'гиас',
#  'дворецкий',
#  'девочка',
#  'досмотреть',
#  'доставлять',
#  'дубляж',
#  'дух',
#  'ева',
#  'евангелиона',
#  'замок',
#  'звать',
#  'июль',
#  'кадр',
#  'картинка',
#  'концовка',
#  'кп',
#  'кровь',
#  'лайт',
#  'манга',
#  'мех',
#  'милый',
#  'миядзака',
#  'мульт',
#  'мультик',
#  'мультфильм',
#  'мусор',
#  'нарисованный',
#  'нарута',
#  'наруто',
#  'наткнуться',
#  'овашка',
#  'опенинг',
#  'пафос',
#  'пересматривать',
#  'пересмотреть',
#  'персонаж',
#  'повседневность',
#  'поделиться',
#  'покемон',
#  'полнометражка',
#  'полнометражный',
#  'призрак',
#  'продолжение',
#  'происходящий',
#  'просмотр',
#  'рейтинг',
#  'рисовка',
#  'саба',
#  'самурай',
#  'сантиметр',
#  'седзе',
#  'сейя',
#  'сенэн',
#  'сериал',
#  'серия',
#  'синкай',
#  'сиська',
#  'скрытый',
#  'смерть',
#  'тайтл',
#  'творение',
#  'тетрадка',
#  'тетрадь',
#  'туалет',
#  'унесённый',
#  'ученик',
#  'фансервис',
#  'фантазия',
#  'формат',
#  'хентай',
#  'ходячий',
#  'штамп',
#  'эльфийский',
#  'эпизод',
#  'японец',
#  'япония',
#  'японский'}

# %%
categs = ['anime', 'art', 'books', 'films', 'food', 'football', 'games', 'music', 'nature', 'travel']
# weights = [len(v) / max([len(v) for v in top_sets.values()]) for v in top_sets.values()] # normal weights per quantity
weights = [1] * 10 # non-existent weights

def words_from_tokens(tokens):
    vec = [0] * 10
    for i in range(len(categs)):
        count = 0
        for t in tokens:
            if t in top_word_sets[categs[i]]:
                count += 1
        if len(tokens) == 0:
            vec[i] = (count / 1)/weights[i]
        else:
            vec[i] = (count / len(tokens))/weights[i]
    vec = np.array(vec, dtype='float32')
    return vec

# %%
def vectors_from_corpus(corpus):
    vectors = [words_from_tokens(text) for text in tqdm(corpus)]
    return vectors

# %%
train_word_vectors = vectors_from_corpus(train_tokens)
# Out:
# 100%|█████████████████████████████████| 87844/87844 [00:04<00:00, 18606.89it/s]

# %%
test_word_vectors = vectors_from_corpus(test_tokens)
# Out:
# 100%|███████████████████████████████████| 1000/1000 [00:00<00:00, 16382.21it/s]

# %%
val_word_vectors = vectors_from_corpus(val_tokens)
# Out:
# 100%|███████████████████████████████████| 1000/1000 [00:00<00:00, 14072.72it/s]

# %%
with open('trigrams_threehundred_sorted.pkl', 'rb') as t:
    top_tri_sets = {k:set(val[:300]) for k, val in (pkl.load(t)).items()}
t.close()

# %%
categs = ['anime', 'art', 'books', 'films', 'food', 'football', 'games', 'music', 'nature', 'travel']
# weights = [len(v) / max([len(v) for v in top_sets.values()]) for v in top_sets.values()] # normal weights per quantity
weights = [1] * 10 # non-existent weights

def tris_from_text(text):
    vec = [0] * 10
    for i in range(len(categs)):
        count = 0
        for trig in top_tri_sets[categs[i]]:
            if trig in text:
                count += 1
        
        if len(text) == 0:
            vec[i] = (count / 1)/weights[i]
        else:
            vec[i] = (count / len(text))/weights[i]
    vec = np.array(vec, dtype='float32')
    return vec

# %%
def trigrams_from_corpus(corpus):
    trigrams = [tris_from_text(text) for text in tqdm(corpus)]
    return trigrams

# %%
train_tri_vectors = trigrams_from_corpus(train_texts)
# Out:
#   0%|                                                | 0/87844 [00:00<?, ?it/s]
#   0%|                                    | 214/87844 [00:00<00:40, 2138.50it/s]
#   0%|▏                                   | 439/87844 [00:00<00:40, 2169.96it/s]
#   1%|▎                                   | 694/87844 [00:00<00:38, 2271.14it/s]
#   1%|▍                                   | 931/87844 [00:00<00:37, 2299.36it/s]
#   1%|▍                                  | 1167/87844 [00:00<00:37, 2316.74it/s]
#   2%|▌                                  | 1402/87844 [00:00<00:37, 2326.15it/s]
#   2%|▋                                  | 1622/87844 [00:00<00:37, 2286.37it/s]
#   2%|▋                                  | 1875/87844 [00:00<00:36, 2353.92it/s]
#   2%|▊                                  | 2099/87844 [00:00<00:36, 2317.93it/s]
#   3%|▉                                  | 2354/87844 [00:01<00:35, 2382.52it/s]
#   3%|█                                  | 2588/87844 [00:01<00:36, 2361.76it/s]
#   3%|█                                  | 2821/87844 [00:01<00:37, 2281.61it/s]
#   3%|█▏                                 | 3048/87844 [00:01<00:37, 2277.70it/s]
#   4%|█▎                                 | 3275/87844 [00:01<00:40, 2092.25it/s]
#   4%|█▍                                 | 3487/87844 [00:01<00:42, 1982.16it/s]
#   4%|█▍                                 | 3688/87844 [00:01<00:44, 1873.17it/s]
#   4%|█▌                                 | 3879/87844 [00:01<00:46, 1798.41it/s]
#   5%|█▌                                 | 4062/87844 [00:01<00:46, 1796.43it/s]
#   5%|█▋                                 | 4244/87844 [00:02<00:46, 1791.91it/s]
#   5%|█▊                                 | 4429/87844 [00:02<00:46, 1808.37it/s]
#   5%|█▊                                 | 4616/87844 [00:02<00:45, 1825.64it/s]
#   5%|█▉                                 | 4800/87844 [00:02<00:45, 1818.01it/s]
#   6%|█▉                                 | 4983/87844 [00:02<00:46, 1794.37it/s]
#   6%|██                                 | 5164/87844 [00:02<00:45, 1798.45it/s]
#   6%|██▏                                | 5345/87844 [00:02<00:47, 1754.22it/s]
#   6%|██▏                                | 5521/87844 [00:02<00:48, 1685.05it/s]
#   6%|██▎                                | 5691/87844 [00:02<00:50, 1630.54it/s]
#   7%|██▎                                | 5861/87844 [00:02<00:49, 1650.45it/s]
#   7%|██▍                                | 6027/87844 [00:03<00:51, 1586.61it/s]
#   7%|██▍                                | 6187/87844 [00:03<00:51, 1571.51it/s]
#   7%|██▌                                | 6364/87844 [00:03<00:50, 1625.90it/s]
#   7%|██▌                                | 6528/87844 [00:03<00:52, 1555.51it/s]
#   8%|██▋                                | 6689/87844 [00:03<00:51, 1571.13it/s]
#   8%|██▋                                | 6848/87844 [00:03<00:51, 1571.73it/s]
#   8%|██▊                                | 7015/87844 [00:03<00:50, 1599.65it/s]
#   8%|██▊                                | 7191/87844 [00:03<00:49, 1644.28it/s]
#   8%|██▉                                | 7384/87844 [00:03<00:46, 1720.37it/s]
#   9%|███                                | 7582/87844 [00:03<00:44, 1790.47it/s]
#   9%|███                                | 7771/87844 [00:04<00:44, 1818.84it/s]
#   9%|███▏                               | 7955/87844 [00:04<00:44, 1787.49it/s]
#   9%|███▏                               | 8136/87844 [00:04<00:44, 1793.80it/s]
#   9%|███▎                               | 8321/87844 [00:04<00:43, 1809.92it/s]
#  10%|███▍                               | 8503/87844 [00:04<00:43, 1807.15it/s]
#  10%|███▍                               | 8703/87844 [00:04<00:42, 1860.61it/s]
#  10%|███▌                               | 8890/87844 [00:04<00:42, 1851.95it/s]
#  10%|███▌                               | 9080/87844 [00:04<00:42, 1865.72it/s]
#  11%|███▋                               | 9273/87844 [00:04<00:41, 1884.15it/s]
#  11%|███▊                               | 9466/87844 [00:04<00:41, 1897.28it/s]
#  11%|███▊                               | 9669/87844 [00:05<00:40, 1934.84it/s]
#  11%|███▉                               | 9863/87844 [00:05<00:41, 1890.67it/s]
#  11%|███▉                              | 10053/87844 [00:05<00:41, 1854.22it/s]
#  12%|███▉                              | 10239/87844 [00:05<00:41, 1850.01it/s]
#  12%|████                              | 10436/87844 [00:05<00:41, 1884.07it/s]
#  12%|████                              | 10639/87844 [00:05<00:40, 1925.21it/s]
#  12%|████▏                             | 10838/87844 [00:05<00:39, 1938.10it/s]
#  13%|████▎                             | 11033/87844 [00:05<00:40, 1879.45it/s]
#  13%|████▎                             | 11222/87844 [00:05<00:43, 1761.11it/s]
#  13%|████▍                             | 11433/87844 [00:06<00:41, 1852.68it/s]
#  13%|████▍                             | 11621/87844 [00:06<00:42, 1786.11it/s]
#  13%|████▌                             | 11802/87844 [00:06<00:43, 1751.17it/s]
#  14%|████▋                             | 11985/87844 [00:06<00:42, 1773.73it/s]
#  14%|████▋                             | 12164/87844 [00:06<00:42, 1772.92it/s]
#  14%|████▊                             | 12360/87844 [00:06<00:41, 1819.73it/s]
#  14%|████▊                             | 12564/87844 [00:06<00:40, 1880.28it/s]
#  15%|████▉                             | 12759/87844 [00:06<00:39, 1900.28it/s]
#  15%|█████                             | 12950/87844 [00:06<00:39, 1902.77it/s]
#  15%|█████                             | 13141/87844 [00:06<00:40, 1843.82it/s]
#  15%|█████▏                            | 13327/87844 [00:07<00:40, 1842.76it/s]
#  15%|█████▏                            | 13526/87844 [00:07<00:39, 1884.20it/s]
#  16%|█████▎                            | 13716/87844 [00:07<00:39, 1871.76it/s]
#  16%|█████▍                            | 13943/87844 [00:07<00:37, 1975.38it/s]
#  16%|█████▍                            | 14148/87844 [00:07<00:36, 1996.77it/s]
#  16%|█████▌                            | 14402/87844 [00:07<00:34, 2111.98it/s]
#  17%|█████▋                            | 14638/87844 [00:07<00:33, 2180.30it/s]
#  17%|█████▊                            | 14865/87844 [00:07<00:33, 2193.22it/s]
#  17%|█████▊                            | 15087/87844 [00:07<00:33, 2181.24it/s]
#  17%|█████▉                            | 15328/87844 [00:07<00:32, 2244.72it/s]
#  18%|██████                            | 15569/87844 [00:08<00:31, 2291.42it/s]
#  18%|██████                            | 15815/87844 [00:08<00:30, 2332.38it/s]
#  18%|██████▏                           | 16050/87844 [00:08<00:31, 2296.01it/s]
#  19%|██████▎                           | 16281/87844 [00:08<00:31, 2292.85it/s]
#  19%|██████▍                           | 16512/87844 [00:08<00:31, 2277.09it/s]
#  19%|██████▍                           | 16747/87844 [00:08<00:30, 2298.00it/s]
#  19%|██████▌                           | 16984/87844 [00:08<00:30, 2318.65it/s]
#  20%|██████▋                           | 17217/87844 [00:08<00:30, 2287.33it/s]
#  20%|██████▊                           | 17455/87844 [00:08<00:30, 2313.89it/s]
#  20%|██████▊                           | 17687/87844 [00:09<00:30, 2315.24it/s]
#  20%|██████▉                           | 17921/87844 [00:09<00:30, 2322.11it/s]
#  21%|███████                           | 18160/87844 [00:09<00:29, 2341.58it/s]
#  21%|███████                           | 18395/87844 [00:09<00:30, 2282.11it/s]
#  21%|███████▏                          | 18640/87844 [00:09<00:29, 2329.54it/s]
#  21%|███████▎                          | 18874/87844 [00:09<00:29, 2318.29it/s]
#  22%|███████▍                          | 19107/87844 [00:09<00:29, 2300.66it/s]
#  22%|███████▍                          | 19338/87844 [00:09<00:29, 2302.96it/s]
#  22%|███████▌                          | 19576/87844 [00:09<00:29, 2325.06it/s]
#  23%|███████▋                          | 19815/87844 [00:09<00:29, 2343.68it/s]
#  23%|███████▊                          | 20050/87844 [00:10<00:28, 2345.07it/s]
#  23%|███████▊                          | 20290/87844 [00:10<00:28, 2360.80it/s]
#  23%|███████▉                          | 20548/87844 [00:10<00:27, 2422.06it/s]
#  24%|████████                          | 20791/87844 [00:10<00:28, 2313.08it/s]
#  24%|████████▏                         | 21027/87844 [00:10<00:28, 2326.47it/s]
#  24%|████████▏                         | 21261/87844 [00:10<00:29, 2288.96it/s]
#  24%|████████▎                         | 21492/87844 [00:10<00:28, 2294.76it/s]
#  25%|████████▍                         | 21733/87844 [00:10<00:28, 2327.66it/s]
#  25%|████████▌                         | 21967/87844 [00:10<00:28, 2296.52it/s]
#  25%|████████▌                         | 22221/87844 [00:10<00:27, 2364.06it/s]
#  26%|████████▋                         | 22473/87844 [00:11<00:27, 2408.28it/s]
#  26%|████████▊                         | 22715/87844 [00:11<00:27, 2334.45it/s]
#  26%|████████▉                         | 22950/87844 [00:11<00:29, 2182.14it/s]
#  26%|████████▉                         | 23171/87844 [00:11<00:29, 2189.96it/s]
#  27%|█████████                         | 23413/87844 [00:11<00:28, 2253.80it/s]
#  27%|█████████▏                        | 23655/87844 [00:11<00:27, 2300.75it/s]
#  27%|█████████▎                        | 23906/87844 [00:11<00:27, 2359.28it/s]
#  27%|█████████▎                        | 24144/87844 [00:11<00:27, 2323.37it/s]
#  28%|█████████▍                        | 24382/87844 [00:11<00:27, 2332.70it/s]
#  28%|█████████▌                        | 24617/87844 [00:11<00:27, 2330.41it/s]
#  28%|█████████▌                        | 24851/87844 [00:12<00:27, 2284.92it/s]
#  29%|█████████▋                        | 25101/87844 [00:12<00:26, 2344.98it/s]
#  29%|█████████▊                        | 25354/87844 [00:12<00:26, 2397.10it/s]
#  29%|█████████▉                        | 25616/87844 [00:12<00:25, 2459.39it/s]
#  29%|██████████                        | 25891/87844 [00:12<00:24, 2532.39it/s]
#  30%|██████████                        | 26146/87844 [00:12<00:24, 2537.11it/s]
#  30%|██████████▏                       | 26407/87844 [00:12<00:24, 2558.01it/s]
#  30%|██████████▎                       | 26664/87844 [00:12<00:24, 2479.47it/s]
#  31%|██████████▍                       | 26918/87844 [00:12<00:24, 2496.80it/s]
#  31%|██████████▌                       | 27169/87844 [00:13<00:24, 2463.38it/s]
#  31%|██████████▌                       | 27438/87844 [00:13<00:23, 2526.73it/s]
#  32%|██████████▋                       | 27699/87844 [00:13<00:23, 2550.61it/s]
#  32%|██████████▊                       | 27974/87844 [00:13<00:22, 2606.81it/s]
#  32%|██████████▉                       | 28237/87844 [00:13<00:22, 2613.17it/s]
#  32%|███████████                       | 28499/87844 [00:13<00:22, 2606.84it/s]
#  33%|███████████▏                      | 28761/87844 [00:13<00:23, 2564.22it/s]
#  33%|███████████▏                      | 29018/87844 [00:13<00:23, 2535.00it/s]
#  33%|███████████▎                      | 29272/87844 [00:13<00:23, 2520.85it/s]
#  34%|███████████▍                      | 29533/87844 [00:13<00:22, 2546.41it/s]
#  34%|███████████▌                      | 29800/87844 [00:14<00:22, 2581.74it/s]
#  34%|███████████▋                      | 30072/87844 [00:14<00:22, 2621.18it/s]
#  35%|███████████▋                      | 30335/87844 [00:14<00:23, 2475.05it/s]
#  35%|███████████▊                      | 30602/87844 [00:14<00:22, 2522.78it/s]
#  35%|███████████▉                      | 30863/87844 [00:14<00:22, 2547.81it/s]
#  35%|████████████                      | 31121/87844 [00:14<00:22, 2556.84it/s]
#  36%|████████████▏                     | 31378/87844 [00:14<00:22, 2560.21it/s]
#  36%|████████████▏                     | 31635/87844 [00:14<00:22, 2517.38it/s]
#  36%|████████████▎                     | 31901/87844 [00:14<00:21, 2558.01it/s]
#  37%|████████████▍                     | 32158/87844 [00:14<00:21, 2561.07it/s]
#  37%|████████████▌                     | 32416/87844 [00:15<00:21, 2566.16it/s]
#  37%|████████████▋                     | 32673/87844 [00:15<00:21, 2543.88it/s]
#  37%|████████████▋                     | 32933/87844 [00:15<00:21, 2559.92it/s]
#  38%|████████████▊                     | 33192/87844 [00:15<00:21, 2568.33it/s]
#  38%|████████████▉                     | 33449/87844 [00:15<00:21, 2568.28it/s]
#  38%|█████████████                     | 33723/87844 [00:15<00:20, 2616.97it/s]
#  39%|█████████████▏                    | 33985/87844 [00:15<00:20, 2578.64it/s]
#  39%|█████████████▎                    | 34247/87844 [00:15<00:20, 2590.37it/s]
#  39%|█████████████▎                    | 34507/87844 [00:15<00:20, 2562.02it/s]
#  40%|█████████████▍                    | 34764/87844 [00:16<00:22, 2378.65it/s]
#  40%|█████████████▌                    | 35005/87844 [00:16<00:23, 2272.57it/s]
#  40%|█████████████▋                    | 35236/87844 [00:16<00:23, 2283.18it/s]
#  40%|█████████████▋                    | 35467/87844 [00:16<00:23, 2243.92it/s]
#  41%|█████████████▊                    | 35693/87844 [00:16<00:23, 2228.28it/s]
#  41%|█████████████▉                    | 35917/87844 [00:16<00:23, 2198.43it/s]
#  41%|█████████████▉                    | 36138/87844 [00:16<00:24, 2112.96it/s]
#  41%|██████████████                    | 36351/87844 [00:16<00:24, 2105.02it/s]
#  42%|██████████████▏                   | 36608/87844 [00:16<00:23, 2225.43it/s]
#  42%|██████████████▎                   | 36848/87844 [00:16<00:22, 2274.61it/s]
#  42%|██████████████▎                   | 37104/87844 [00:17<00:21, 2352.86it/s]
#  43%|██████████████▍                   | 37353/87844 [00:17<00:21, 2391.89it/s]
#  43%|██████████████▌                   | 37594/87844 [00:17<00:20, 2396.80it/s]
#  43%|██████████████▋                   | 37858/87844 [00:17<00:20, 2464.42it/s]
#  43%|██████████████▊                   | 38112/87844 [00:17<00:20, 2486.09it/s]
#  44%|██████████████▊                   | 38373/87844 [00:17<00:19, 2521.51it/s]
#  44%|██████████████▉                   | 38630/87844 [00:17<00:19, 2535.31it/s]
#  44%|███████████████                   | 38885/87844 [00:17<00:19, 2509.17it/s]
#  45%|███████████████▏                  | 39144/87844 [00:17<00:19, 2532.36it/s]
#  45%|███████████████▏                  | 39399/87844 [00:17<00:19, 2537.07it/s]
#  45%|███████████████▎                  | 39653/87844 [00:18<00:20, 2387.08it/s]
#  45%|███████████████▍                  | 39900/87844 [00:18<00:19, 2410.86it/s]
#  46%|███████████████▌                  | 40168/87844 [00:18<00:19, 2485.25it/s]
#  46%|███████████████▋                  | 40429/87844 [00:18<00:18, 2520.82it/s]
#  46%|███████████████▋                  | 40683/87844 [00:18<00:18, 2510.98it/s]
#  47%|███████████████▊                  | 40963/87844 [00:18<00:18, 2590.71it/s]
#  47%|███████████████▉                  | 41224/87844 [00:18<00:18, 2580.19it/s]
#  47%|████████████████                  | 41483/87844 [00:18<00:18, 2566.52it/s]
#  48%|████████████████▏                 | 41741/87844 [00:18<00:18, 2539.74it/s]
#  48%|████████████████▎                 | 41996/87844 [00:18<00:18, 2527.03it/s]
#  48%|████████████████▎                 | 42256/87844 [00:19<00:17, 2547.98it/s]
#  48%|████████████████▍                 | 42517/87844 [00:19<00:17, 2565.30it/s]
#  49%|████████████████▌                 | 42774/87844 [00:19<00:17, 2558.55it/s]
#  49%|████████████████▋                 | 43031/87844 [00:19<00:17, 2553.12it/s]
#  49%|████████████████▊                 | 43293/87844 [00:19<00:17, 2572.14it/s]
#  50%|████████████████▊                 | 43551/87844 [00:19<00:17, 2527.51it/s]
#  50%|████████████████▉                 | 43806/87844 [00:19<00:17, 2532.81it/s]
#  50%|█████████████████                 | 44067/87844 [00:19<00:17, 2554.05it/s]
#  50%|█████████████████▏                | 44326/87844 [00:19<00:16, 2562.23it/s]
#  51%|█████████████████▎                | 44583/87844 [00:20<00:17, 2504.02it/s]
#  51%|█████████████████▎                | 44834/87844 [00:20<00:17, 2505.27it/s]
#  51%|█████████████████▍                | 45105/87844 [00:20<00:16, 2562.15it/s]
#  52%|█████████████████▌                | 45373/87844 [00:20<00:16, 2595.21it/s]
#  52%|█████████████████▋                | 45633/87844 [00:20<00:16, 2557.06it/s]
#  52%|█████████████████▊                | 45896/87844 [00:20<00:16, 2577.98it/s]
#  53%|█████████████████▊                | 46155/87844 [00:20<00:16, 2581.02it/s]
#  53%|█████████████████▉                | 46415/87844 [00:20<00:16, 2586.24it/s]
#  53%|██████████████████                | 46688/87844 [00:20<00:15, 2626.99it/s]
#  53%|██████████████████▏               | 46951/87844 [00:20<00:16, 2437.29it/s]
#  54%|██████████████████▎               | 47227/87844 [00:21<00:16, 2525.12it/s]
#  54%|██████████████████▍               | 47483/87844 [00:21<00:16, 2440.36it/s]
#  54%|██████████████████▍               | 47745/87844 [00:21<00:16, 2490.47it/s]
#  55%|██████████████████▌               | 48004/87844 [00:21<00:15, 2517.63it/s]
#  55%|██████████████████▋               | 48258/87844 [00:21<00:15, 2516.26it/s]
#  55%|██████████████████▊               | 48518/87844 [00:21<00:15, 2539.88it/s]
#  56%|██████████████████▉               | 48773/87844 [00:21<00:15, 2534.78it/s]
#  56%|██████████████████▉               | 49030/87844 [00:21<00:15, 2544.71it/s]
#  56%|███████████████████               | 49285/87844 [00:21<00:15, 2538.26it/s]
#  56%|███████████████████▏              | 49540/87844 [00:21<00:15, 2446.08it/s]
#  57%|███████████████████▎              | 49794/87844 [00:22<00:15, 2471.60it/s]
#  57%|███████████████████▎              | 50042/87844 [00:22<00:15, 2473.66it/s]
#  57%|███████████████████▍              | 50290/87844 [00:22<00:15, 2402.53it/s]
#  58%|███████████████████▌              | 50532/87844 [00:22<00:15, 2378.74it/s]
#  58%|███████████████████▋              | 50779/87844 [00:22<00:15, 2404.74it/s]
#  58%|███████████████████▋              | 51020/87844 [00:22<00:15, 2369.98it/s]
#  58%|███████████████████▊              | 51258/87844 [00:22<00:15, 2323.32it/s]
#  59%|███████████████████▉              | 51516/87844 [00:22<00:15, 2393.33it/s]
#  59%|████████████████████              | 51757/87844 [00:22<00:15, 2355.43it/s]
#  59%|████████████████████              | 51994/87844 [00:23<00:15, 2337.28it/s]
#  59%|████████████████████▏             | 52229/87844 [00:23<00:15, 2319.10it/s]
#  60%|████████████████████▎             | 52462/87844 [00:23<00:15, 2307.73it/s]
#  60%|████████████████████▍             | 52702/87844 [00:23<00:15, 2334.14it/s]
#  60%|████████████████████▍             | 52936/87844 [00:23<00:15, 2241.38it/s]
#  61%|████████████████████▌             | 53180/87844 [00:23<00:15, 2297.02it/s]
#  61%|████████████████████▋             | 53426/87844 [00:23<00:14, 2342.14it/s]
#  61%|████████████████████▊             | 53676/87844 [00:23<00:14, 2385.40it/s]
#  61%|████████████████████▊             | 53916/87844 [00:23<00:14, 2368.02it/s]
#  62%|████████████████████▉             | 54154/87844 [00:23<00:14, 2371.09it/s]
#  62%|█████████████████████             | 54392/87844 [00:24<00:14, 2344.39it/s]
#  62%|█████████████████████▏            | 54635/87844 [00:24<00:14, 2368.51it/s]
#  62%|█████████████████████▏            | 54880/87844 [00:24<00:13, 2391.85it/s]
#  63%|█████████████████████▎            | 55120/87844 [00:24<00:13, 2393.66it/s]
#  63%|█████████████████████▍            | 55403/87844 [00:24<00:12, 2508.90it/s]
#  63%|█████████████████████▌            | 55656/87844 [00:24<00:12, 2484.79it/s]
#  64%|█████████████████████▋            | 55906/87844 [00:24<00:13, 2402.55it/s]
#  64%|█████████████████████▋            | 56152/87844 [00:24<00:13, 2418.32it/s]
#  64%|█████████████████████▊            | 56395/87844 [00:24<00:13, 2398.45it/s]
#  64%|█████████████████████▉            | 56636/87844 [00:24<00:13, 2386.76it/s]
#  65%|██████████████████████            | 56876/87844 [00:25<00:13, 2368.87it/s]
#  65%|██████████████████████            | 57114/87844 [00:25<00:13, 2316.03it/s]
#  65%|██████████████████████▏           | 57362/87844 [00:25<00:12, 2360.84it/s]
#  66%|██████████████████████▎           | 57599/87844 [00:25<00:13, 2321.28it/s]
#  66%|██████████████████████▍           | 57833/87844 [00:25<00:12, 2326.46it/s]
#  66%|██████████████████████▍           | 58075/87844 [00:25<00:12, 2352.13it/s]
#  66%|██████████████████████▌           | 58311/87844 [00:25<00:12, 2345.72it/s]
#  67%|██████████████████████▋           | 58556/87844 [00:25<00:12, 2374.63it/s]
#  67%|██████████████████████▊           | 58794/87844 [00:25<00:12, 2326.92it/s]
#  67%|██████████████████████▊           | 59037/87844 [00:25<00:12, 2355.86it/s]
#  67%|██████████████████████▉           | 59273/87844 [00:26<00:12, 2318.28it/s]
#  68%|███████████████████████           | 59506/87844 [00:26<00:12, 2321.19it/s]
#  68%|███████████████████████▏          | 59757/87844 [00:26<00:11, 2374.30it/s]
#  68%|███████████████████████▏          | 60003/87844 [00:26<00:11, 2398.97it/s]
#  69%|███████████████████████▎          | 60244/87844 [00:26<00:11, 2372.57it/s]
#  69%|███████████████████████▍          | 60492/87844 [00:26<00:11, 2402.82it/s]
#  69%|███████████████████████▌          | 60733/87844 [00:26<00:11, 2288.01it/s]
#  69%|███████████████████████▌          | 60964/87844 [00:26<00:11, 2267.05it/s]
#  70%|███████████████████████▋          | 61192/87844 [00:26<00:11, 2236.99it/s]
#  70%|███████████████████████▊          | 61417/87844 [00:27<00:11, 2240.41it/s]
#  70%|███████████████████████▊          | 61642/87844 [00:27<00:12, 2171.32it/s]
#  70%|███████████████████████▉          | 61860/87844 [00:27<00:12, 2147.75it/s]
#  71%|████████████████████████          | 62076/87844 [00:27<00:12, 2106.85it/s]
#  71%|████████████████████████          | 62325/87844 [00:27<00:11, 2208.40it/s]
#  71%|████████████████████████▏         | 62573/87844 [00:27<00:11, 2282.41it/s]
#  72%|████████████████████████▎         | 62818/87844 [00:27<00:10, 2329.70it/s]
#  72%|████████████████████████▍         | 63054/87844 [00:27<00:10, 2337.60it/s]
#  72%|████████████████████████▍         | 63289/87844 [00:27<00:10, 2272.84it/s]
#  72%|████████████████████████▌         | 63518/87844 [00:27<00:10, 2257.26it/s]
#  73%|████████████████████████▋         | 63747/87844 [00:28<00:10, 2266.50it/s]
#  73%|████████████████████████▊         | 63975/87844 [00:28<00:10, 2230.04it/s]
#  73%|████████████████████████▊         | 64199/87844 [00:28<00:10, 2180.35it/s]
#  73%|████████████████████████▉         | 64418/87844 [00:28<00:10, 2150.62it/s]
#  74%|█████████████████████████         | 64636/87844 [00:28<00:10, 2158.88it/s]
#  74%|█████████████████████████         | 64853/87844 [00:28<00:10, 2136.20it/s]
#  74%|█████████████████████████▏        | 65086/87844 [00:28<00:10, 2190.43it/s]
#  74%|█████████████████████████▎        | 65323/87844 [00:28<00:10, 2240.92it/s]
#  75%|█████████████████████████▎        | 65548/87844 [00:28<00:09, 2243.15it/s]
#  75%|█████████████████████████▍        | 65773/87844 [00:28<00:10, 2179.45it/s]
#  75%|█████████████████████████▌        | 66009/87844 [00:29<00:09, 2230.21it/s]
#  75%|█████████████████████████▋        | 66243/87844 [00:29<00:09, 2261.58it/s]
#  76%|█████████████████████████▋        | 66470/87844 [00:29<00:09, 2210.67it/s]
#  76%|█████████████████████████▊        | 66710/87844 [00:29<00:09, 2263.43it/s]
#  76%|█████████████████████████▉        | 66954/87844 [00:29<00:09, 2313.16it/s]
#  77%|██████████████████████████        | 67214/87844 [00:29<00:08, 2391.87it/s]
#  77%|██████████████████████████        | 67455/87844 [00:29<00:08, 2382.64it/s]
#  77%|██████████████████████████▏       | 67695/87844 [00:29<00:08, 2372.50it/s]
#  77%|██████████████████████████▎       | 67955/87844 [00:29<00:08, 2435.97it/s]
#  78%|██████████████████████████▍       | 68202/87844 [00:29<00:08, 2445.56it/s]
#  78%|██████████████████████████▍       | 68448/87844 [00:30<00:08, 2420.31it/s]
#  78%|██████████████████████████▌       | 68691/87844 [00:30<00:07, 2422.09it/s]
#  78%|██████████████████████████▋       | 68942/87844 [00:30<00:07, 2446.29it/s]
#  79%|██████████████████████████▊       | 69187/87844 [00:30<00:07, 2439.38it/s]
#  79%|██████████████████████████▉       | 69437/87844 [00:30<00:07, 2456.46it/s]
#  79%|██████████████████████████▉       | 69683/87844 [00:30<00:07, 2392.49it/s]
#  80%|███████████████████████████       | 69941/87844 [00:30<00:07, 2445.24it/s]
#  80%|███████████████████████████▏      | 70187/87844 [00:30<00:07, 2412.87it/s]
#  80%|███████████████████████████▎      | 70435/87844 [00:30<00:07, 2432.18it/s]
#  80%|███████████████████████████▎      | 70679/87844 [00:31<00:07, 2405.12it/s]
#  81%|███████████████████████████▍      | 70926/87844 [00:31<00:06, 2423.78it/s]
#  81%|███████████████████████████▌      | 71169/87844 [00:31<00:06, 2416.75it/s]
#  81%|███████████████████████████▋      | 71413/87844 [00:31<00:06, 2422.18it/s]
#  82%|███████████████████████████▋      | 71656/87844 [00:31<00:06, 2366.60it/s]
#  82%|███████████████████████████▊      | 71894/87844 [00:31<00:06, 2356.02it/s]
#  82%|███████████████████████████▉      | 72131/87844 [00:31<00:06, 2359.69it/s]
#  82%|████████████████████████████      | 72368/87844 [00:31<00:06, 2334.22it/s]
#  83%|████████████████████████████      | 72602/87844 [00:31<00:06, 2335.46it/s]
#  83%|████████████████████████████▏     | 72860/87844 [00:31<00:06, 2403.25it/s]
#  83%|████████████████████████████▎     | 73101/87844 [00:32<00:06, 2390.26it/s]
#  83%|████████████████████████████▍     | 73343/87844 [00:32<00:06, 2398.57it/s]
#  84%|████████████████████████████▍     | 73589/87844 [00:32<00:05, 2416.28it/s]
#  84%|████████████████████████████▌     | 73838/87844 [00:32<00:05, 2436.74it/s]
#  84%|████████████████████████████▋     | 74087/87844 [00:32<00:05, 2451.87it/s]
#  85%|████████████████████████████▊     | 74346/87844 [00:32<00:05, 2491.06it/s]
#  85%|████████████████████████████▉     | 74612/87844 [00:32<00:05, 2538.86it/s]
#  85%|████████████████████████████▉     | 74867/87844 [00:32<00:05, 2534.13it/s]
#  86%|█████████████████████████████     | 75121/87844 [00:32<00:05, 2454.45it/s]
#  86%|█████████████████████████████▏    | 75368/87844 [00:32<00:05, 2366.64it/s]
#  86%|█████████████████████████████▎    | 75606/87844 [00:33<00:05, 2281.44it/s]
#  86%|█████████████████████████████▎    | 75836/87844 [00:33<00:05, 2279.70it/s]
#  87%|█████████████████████████████▍    | 76067/87844 [00:33<00:05, 2288.23it/s]
#  87%|█████████████████████████████▌    | 76297/87844 [00:33<00:05, 2291.27it/s]
#  87%|█████████████████████████████▌    | 76537/87844 [00:33<00:04, 2322.27it/s]
#  87%|█████████████████████████████▋    | 76782/87844 [00:33<00:04, 2358.60it/s]
#  88%|█████████████████████████████▊    | 77021/87844 [00:33<00:04, 2367.43it/s]
#  88%|█████████████████████████████▉    | 77268/87844 [00:33<00:04, 2389.83it/s]
#  88%|█████████████████████████████▉    | 77508/87844 [00:33<00:04, 2349.16it/s]
#  89%|██████████████████████████████    | 77760/87844 [00:33<00:04, 2396.24it/s]
#  89%|██████████████████████████████▏   | 78054/87844 [00:34<00:03, 2536.19it/s]
#  89%|██████████████████████████████▎   | 78341/87844 [00:34<00:03, 2627.41it/s]
#  89%|██████████████████████████████▍   | 78607/87844 [00:34<00:03, 2590.38it/s]
#  90%|██████████████████████████████▌   | 78868/87844 [00:34<00:03, 2572.53it/s]
#  90%|██████████████████████████████▋   | 79131/87844 [00:34<00:03, 2588.96it/s]
#  90%|██████████████████████████████▋   | 79391/87844 [00:34<00:03, 2583.99it/s]
#  91%|██████████████████████████████▊   | 79672/87844 [00:34<00:03, 2647.33it/s]
#  91%|██████████████████████████████▉   | 79938/87844 [00:34<00:03, 2625.65it/s]
#  91%|███████████████████████████████   | 80202/87844 [00:34<00:02, 2575.21it/s]
#  92%|███████████████████████████████▏  | 80461/87844 [00:35<00:02, 2563.73it/s]
#  92%|███████████████████████████████▎  | 80746/87844 [00:35<00:02, 2642.87it/s]
#  92%|███████████████████████████████▎  | 81012/87844 [00:35<00:02, 2555.69it/s]
#  93%|███████████████████████████████▍  | 81269/87844 [00:35<00:02, 2506.99it/s]
#  93%|███████████████████████████████▌  | 81556/87844 [00:35<00:02, 2605.44it/s]
#  93%|███████████████████████████████▋  | 81819/87844 [00:35<00:02, 2444.23it/s]
#  93%|███████████████████████████████▊  | 82080/87844 [00:35<00:02, 2490.79it/s]
#  94%|███████████████████████████████▊  | 82336/87844 [00:35<00:02, 2510.09it/s]
#  94%|███████████████████████████████▉  | 82609/87844 [00:35<00:02, 2571.50it/s]
#  94%|████████████████████████████████  | 82868/87844 [00:35<00:01, 2508.90it/s]
#  95%|████████████████████████████████▏ | 83123/87844 [00:36<00:01, 2520.46it/s]
#  95%|████████████████████████████████▎ | 83389/87844 [00:36<00:01, 2560.34it/s]
#  95%|████████████████████████████████▍ | 83646/87844 [00:36<00:01, 2547.42it/s]
#  96%|████████████████████████████████▍ | 83912/87844 [00:36<00:01, 2571.82it/s]
#  96%|████████████████████████████████▌ | 84170/87844 [00:36<00:01, 2565.75it/s]
#  96%|████████████████████████████████▋ | 84427/87844 [00:36<00:01, 2558.61it/s]
#  96%|████████████████████████████████▊ | 84699/87844 [00:36<00:01, 2604.04it/s]
#  97%|████████████████████████████████▉ | 84960/87844 [00:36<00:01, 2597.17it/s]
#  97%|████████████████████████████████▉ | 85221/87844 [00:36<00:01, 2600.56it/s]
#  97%|█████████████████████████████████ | 85496/87844 [00:36<00:00, 2642.31it/s]
#  98%|█████████████████████████████████▏| 85761/87844 [00:37<00:00, 2589.75it/s]
#  98%|█████████████████████████████████▎| 86034/87844 [00:37<00:00, 2626.84it/s]
#  98%|█████████████████████████████████▍| 86298/87844 [00:37<00:00, 2407.05it/s]
#  99%|█████████████████████████████████▍| 86543/87844 [00:37<00:00, 2059.12it/s]
#  99%|█████████████████████████████████▌| 86761/87844 [00:37<00:00, 1984.54it/s]
#  99%|█████████████████████████████████▋| 86969/87844 [00:37<00:00, 1894.74it/s]
#  99%|█████████████████████████████████▋| 87166/87844 [00:37<00:00, 1809.66it/s]
#  99%|█████████████████████████████████▊| 87360/87844 [00:37<00:00, 1845.43it/s]
# 100%|█████████████████████████████████▉| 87549/87844 [00:38<00:00, 1799.25it/s]
# 100%|█████████████████████████████████▉| 87733/87844 [00:38<00:00, 1757.34it/s]
# 100%|██████████████████████████████████| 87844/87844 [00:38<00:00, 2298.70it/s]

# %%
test_tri_vectors = trigrams_from_corpus(test_texts)
# Out:
#   0%|                                                 | 0/1000 [00:00<?, ?it/s]
#  20%|███████▏                             | 195/1000 [00:00<00:00, 1948.59it/s]
#  39%|██████████████▌                      | 392/1000 [00:00<00:00, 1954.18it/s]
#  61%|██████████████████████▋              | 614/1000 [00:00<00:00, 2013.29it/s]
#  86%|███████████████████████████████▉     | 862/1000 [00:00<00:00, 2133.45it/s]
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 2041.61it/s]

# %%
val_tri_vectors = trigrams_from_corpus(val_texts)
# Out:
#   0%|                                                 | 0/1000 [00:00<?, ?it/s]
#  20%|███████▌                             | 204/1000 [00:00<00:00, 2038.52it/s]
#  40%|██████████████▋                      | 396/1000 [00:00<00:00, 1994.58it/s]
#  63%|███████████████████████▎             | 630/1000 [00:00<00:00, 2086.39it/s]
#  86%|███████████████████████████████▉     | 863/1000 [00:00<00:00, 2153.41it/s]
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 2076.61it/s]

# %%
def joint_vectors(vectors, word_vectors, tri_vectors):
    joint = [np.concatenate([vectors[i], word_vectors[i], tri_vectors[i]]) for i in tqdm(range(len(vectors)))]
    return np.array(joint)

# %%
train = joint_vectors(train_vectors, train_word_vectors, train_tri_vectors)
# Out:
#   0%|                                                | 0/87844 [00:00<?, ?it/s]
#  31%|█████████▉                      | 27357/87844 [00:00<00:00, 273349.33it/s]
#  62%|███████████████████▊            | 54305/87844 [00:00<00:00, 271820.78it/s]
#  93%|█████████████████████████████▊  | 81703/87844 [00:00<00:00, 272406.53it/s]
# 100%|████████████████████████████████| 87844/87844 [00:00<00:00, 267324.04it/s]

# %%
test = joint_vectors(test_vectors, test_word_vectors, test_tri_vectors)
# Out:
#   0%|                                                 | 0/1000 [00:00<?, ?it/s]
# 100%|██████████████████████████████████| 1000/1000 [00:00<00:00, 124882.51it/s]

# %%
val = joint_vectors(val_vectors, val_word_vectors, val_tri_vectors)
# Out:
#   0%|                                                 | 0/1000 [00:00<?, ?it/s]
# 100%|██████████████████████████████████| 1000/1000 [00:00<00:00, 124915.98it/s]

# %%
with open('Train_'+str(dim+20)+'.pkl', 'wb') as tr:
    pkl.dump(train, tr)

# %%
with open('Test_'+str(dim+20)+'.pkl', 'wb') as tst:
    pkl.dump(test, tst)

# %%
with open('Val_'+str(dim+20)+'.pkl', 'wb') as vl:
    pkl.dump(val, vl)

# %%
def joint_vectors_tris(vectors, tri_vectors):
    joint = [np.concatenate([vectors[i], tri_vectors[i]]) for i in tqdm(range(len(vectors)))]
    return np.array(joint)

# %%
train_tri = joint_vectors_tris(train_vectors, train_tri_vectors)
# Out:
#   0%|                                                | 0/87844 [00:00<?, ?it/s]
#  38%|████████████▎                   | 33804/87844 [00:00<00:00, 337799.51it/s]
#  73%|███████████████████████▎        | 63870/87844 [00:00<00:00, 325655.59it/s]
# 100%|████████████████████████████████| 87844/87844 [00:00<00:00, 325119.07it/s]

# %%
test_tri = joint_vectors_tris(test_vectors, test_tri_vectors)
# Out:
#   0%|                                                 | 0/1000 [00:00<?, ?it/s]
# 100%|██████████████████████████████████| 1000/1000 [00:00<00:00, 142755.66it/s]

# %%
val_tri = joint_vectors_tris(val_vectors, val_tri_vectors)
# Out:
#   0%|                                                 | 0/1000 [00:00<?, ?it/s]
# 100%|██████████████████████████████████| 1000/1000 [00:00<00:00, 124908.54it/s]

# %%
with open('Train_'+str(dim+10)+'_tris.pkl', 'wb') as tr1:
    pkl.dump(train_tri, tr1)

# %%
with open('Test_'+str(dim+10)+'_tris.pkl', 'wb') as tst1:
    pkl.dump(test_tri, tst1)

# %%
with open('Val_'+str(dim+10)+'_tris.pkl', 'wb') as vl1:
    pkl.dump(val_tri, vl1)

# %%
def joint_vectors_twenty(word_vectors, tri_vectors):
    joint = [np.concatenate([word_vectors[i], tri_vectors[i]]) for i in tqdm(range(len(word_vectors)))]
    return np.array(joint)

# %%
train_tw = joint_vectors_tris(train_word_vectors, train_tri_vectors)
# Out:
#   0%|                                                | 0/87844 [00:00<?, ?it/s]
#  46%|██████████████▌                 | 40077/87844 [00:00<00:00, 400448.63it/s]
# 100%|████████████████████████████████| 87844/87844 [00:00<00:00, 444830.25it/s]

# %%
test_tw = joint_vectors_tris(test_word_vectors, test_tri_vectors)
# Out:
#   0%|                                                 | 0/1000 [00:00<?, ?it/s]
# 100%|██████████████████████████████████| 1000/1000 [00:00<00:00, 166566.22it/s]

# %%
val_tw = joint_vectors_tris(val_word_vectors, val_tri_vectors)
# Out:
#   0%|                                                 | 0/1000 [00:00<?, ?it/s]
# 100%|██████████████████████████████████| 1000/1000 [00:00<00:00, 166486.88it/s]

# %%
with open('Train_twenty.pkl', 'wb') as tw1:
    pkl.dump(train_tw, tw1)

# %%
with open('Test_twenty.pkl', 'wb') as tw2:
    pkl.dump(test_tw, tw2)

# %%
with open('Val_twenty.pkl', 'wb') as tw3:
    pkl.dump(val_tw, tw3)

# %%
def joint_vector_words(vectors, word_vectors):
    joint = [np.concatenate([vectors[i], word_vectors[i]]) for i in tqdm(range(len(vectors)))]
    return np.array(joint)

# %%
train_words = joint_vector_words(train_vectors, train_word_vectors)
# Out:
#   0%|                                                | 0/87844 [00:00<?, ?it/s]
#  37%|███████████▉                    | 32833/87844 [00:00<00:00, 328097.20it/s]
#  74%|███████████████████████▊        | 65275/87844 [00:00<00:00, 326747.74it/s]
# 100%|████████████████████████████████| 87844/87844 [00:00<00:00, 324912.36it/s]

# %%
test_words = joint_vector_words(test_vectors, test_word_vectors)
# Out:
#   0%|                                                 | 0/1000 [00:00<?, ?it/s]
# 100%|██████████████████████████████████| 1000/1000 [00:00<00:00, 142716.80it/s]

# %%
val_words = joint_vector_words(val_vectors, val_word_vectors)
# Out:
#   0%|                                                 | 0/1000 [00:00<?, ?it/s]
# 100%|██████████████████████████████████| 1000/1000 [00:00<00:00, 124904.82it/s]

# %%
with open('Train_'+str(dim+10)+'_allwords.pkl', 'wb') as w1:
    pkl.dump(train_words, w1)

# %%
with open('Test_'+str(dim+10)+'_allwords.pkl', 'wb') as w2:
    pkl.dump(test_words, w2)

# %%
with open('Val_'+str(dim+10)+'_allwords.pkl', 'wb') as w3:
    pkl.dump(val_words, w3)
