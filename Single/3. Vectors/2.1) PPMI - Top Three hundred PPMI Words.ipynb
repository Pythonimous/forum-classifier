# %%
import pickle as pkl
import math
from tqdm import tqdm

# %%
with open('Matrix Absolute Nonsmooth.pkl', 'rb') as m1:
    wout_smoothing = pkl.load(m1)
m1.close()

# %%
with open('Matrix Absolute Add2 Lessthan0.01.pkl', 'rb') as m2:
    with_smoothing = pkl.load(m2)
m2.close()

# %%
def p_wc(word, context_word, counts, total_counts):
    return counts[word][context_word] / total_counts

# %%
def p_w(word, counts, total_counts):
    return sum(counts[word].values()) / total_counts

# %%
def p_c(context_word, counts, total_counts):
    return sum(freqs.get(context_word, 0) for freqs in counts.values()) / total_counts

# %%
def pmi(word, context_word, counts, total_counts):
    ans = (p_wc(word, context_word, counts, total_counts) /
          (p_w(word, counts, total_counts) * p_c(context_word, counts, total_counts)))
    if ans:
        return math.log2(ans)
    else:
        return 0

# %%
def ppmi(word, context_word, counts, total_counts):
    ans = pmi(word, context_word, counts, total_counts)
    return ans if ans > 0 else 0

# %%
def get_total_counts(counts):
    """counts is a dict of dicts"""
    return sum([sum(vals.values()) for vals in counts.values()])

# %%
def build_matrix(counts):
    total_counts = get_total_counts(counts)
    total_words = len(counts)
    print('working out PPMI')
    for w, contexts in tqdm(counts.items()):
        for c in contexts:
            counts[w][c] = ppmi(w, c, counts, total_counts)
    print('done with PPMI')
    return counts

# %%
smoothppmi = build_matrix(with_smoothing)
# Out:
# working out PPMI
# 100%|█████████████████████████████████████| 2408/2408 [00:11<00:00, 213.94it/s]
# done with PPMI

# %%
with open('PPMIs Add-2 0.01.pkl', 'wb') as p1:
    pkl.dump(smoothppmi, p1)
p1.close()

# %%
def rank_words(counts):
    mean_ppmi = {}
    top_ppmi = {}
    for w, contexts in counts.items():
        vals = list(contexts.values())
        mean_ppmi[w] = sum(vals) / len(vals)
        top_ppmi[w] = max(vals)
    order_mean = sorted(mean_ppmi, key=mean_ppmi.get, reverse=True)
    order_top = sorted(top_ppmi, key=top_ppmi.get, reverse=True)
  #  print(order_mean, file=open('words by mean ppmi no lem.txt', 'w', encoding='utf-8'))
  #  print(order_top, file=open('words by top ppmi no lem.txt', 'w', encoding='utf-8'))
    return order_top

# %%
categs = ['anime', 'art', 'books', 'films', 'food', 'football', 'games', 'music', 'nature', 'travel']

# %%
anime_ppmi = {}
for w, contexts in smoothppmi.items():
    anime_ppmi[w] = contexts['anime']
anime_top_threehundred = sorted(anime_ppmi, key = anime_ppmi.get, reverse=True)[:300]
print(anime_top_threehundred)
# Out:
# ['мультфильм', 'сейя', 'бибоп', 'аниме', 'наруто', 'девочка', 'нарута', 'пересмотреть', 'евангелиона', 'анимэ', 'хентай', 'зацепить', 'манга', 'опенинг', 'дворецкий', 'синкай', 'саба', 'эстетика', 'смотреть', 'овашка', 'анимешник', 'блич', 'краска', 'гиас', 'жанр', 'повседневность', 'школьный', 'призрак', 'полнометражка', 'полнометражный', 'нарисованный', 'тетрадь', 'просмотр', 'досмотреть', 'рисовка', 'созданный', 'анимешный', 'миядзака', 'экранизация', 'студия', 'приём', 'кадр', 'глаз', 'показаться', 'эпизод', 'фансервис', 'акир', 'арка', 'арт', 'японский', 'тайтл', 'тетрадка', 'сенэн', 'культура', 'сестра', 'ходячий', 'мех', 'добрый', 'унесённый', 'рисовать', 'япония', 'концовка', 'выбраться', 'шишкин', 'подойти', 'туалет', 'скрытый', 'эстетический', 'ван', 'палец', 'оставить', 'семь', 'ева', 'седзе', 'боевой', 'особо', 'верный', 'потрясающий', 'анимешка', 'мастерская', 'японец', 'алхимик', 'достоинство', 'голливудский', 'классик', 'лайт', 'эльфийский', 'туристический', 'ирония', 'прокат', 'костюм', 'композитор', 'ранее', 'смерть', 'репина', 'философия', 'змея', 'сериал', 'представлять', 'цветовой', 'нормальный', 'рембрандт', 'дневник', 'делиться', 'дюрер', 'мальчик', 'попытка', 'отпуск', 'исландия', 'ученик', 'картинка', 'дуэт', 'милый', 'великолепный', 'импрессионизм', 'святой', 'корова', 'героиня', 'наблюдать', 'покемон', 'кровь', 'мелодия', 'кинотеатр', 'копировать', 'подниматься', 'продолжение', 'создание', 'сиська', 'дубляж', 'ребята', 'нечто', 'ждать', 'домой', 'захотеться', 'камчатка', 'характерный', 'летний', 'удаться', 'нота', 'контраст', 'рельеф', 'ценность', 'дух', 'запах', 'пересматривать', 'время', 'розовый', 'надежда', 'отдыхающий', 'стараться', 'мера', 'википедия', 'воробей', 'мультик', 'мульт', 'путешествие', 'снова', 'подросток', 'удаваться', 'описанный', 'посетить', 'картина', 'приятно', 'возраст', 'поделиться', 'жалко', 'знакомство', 'встречаться', 'десять', 'фантазия', 'серия', 'истинный', 'думать', 'код', 'лида', 'лёд', 'оторваться', 'шедевр', 'красивый', 'рисовальщик', 'воображение', 'причём', 'происходящий', 'действительно', 'звучать', 'замок', 'приходить', 'нету', 'манера', 'мочь', 'мусор', 'прелесть', 'весёлый', 'рай', 'приходиться', 'вопрос', 'встретить', 'искать', 'сантиметр', 'деревня', 'равно', 'прекрасный', 'кп', 'издание', 'мёд', 'прикольный', 'пр', 'одновременно', 'напоминать', 'доставлять', 'желание', 'звать', 'смесь', 'наткнуться', 'утка', 'леса', 'кинг', 'день', 'среди', 'штамп', 'порой', 'речка', 'потерять', 'самурай', 'бесплатно', 'врубель', 'прочитать', 'волос', 'чей', 'кот', 'интрига', 'формат', 'номер', 'начать', 'студент', 'шаг', 'общий', 'страшно', 'творение', 'писать', 'разбираться', 'античный', 'отлично', 'кто', 'въезд', 'прага', 'получить', 'достаточно', 'вообще', 'поляна', 'просто', 'сутки', 'ритм', 'круиз', 'пафос', 'образование', 'сложный', 'драма', 'фотка', 'килограмм', 'именно', 'рейтинг', 'умный', 'заслуживать', 'вампир', 'властелин', 'увлечение', 'музыкальный', 'выложить', 'абстрактный', 'ощущение', 'зря', 'утро', 'чудо', 'облако', 'единственный', 'сон', 'нежный', 'закат', 'персонаж', 'учитель', 'фантастика', 'холодильник', 'откуда', 'джон', 'рисунок', 'редкий', 'одиночество', 'повествование', 'плавать', 'июль', 'вовсе', 'мнение', 'информация', 'триллер', 'воспоминание', 'акула', 'фанат', 'побережье', 'остановиться']

# %%
art_ppmi = {}
for w, contexts in smoothppmi.items():
    art_ppmi[w] = contexts['art']
art_top_threehundred = sorted(art_ppmi, key = art_ppmi.get, reverse=True)[:300]
print(art_top_threehundred)
# Out:
# ['живопись', 'репина', 'краска', 'рембрандт', 'мастерская', 'врубель', 'картина', 'дюрер', 'шишкин', 'рисовальщик', 'импрессионизм', 'холст', 'скульптор', 'рельеф', 'эстетика', 'рисовать', 'айвазовский', 'цветовой', 'живописец', 'глазунов', 'магритта', 'архитектор', 'шилов', 'сальвадор', 'эстетический', 'босха', 'современник', 'соцреализм', 'декоративный', 'иллюстрация', 'леонардо', 'античный', 'гога', 'скульптура', 'нарисованный', 'рисунок', 'стекло', 'портрет', 'младенец', 'искусствовед', 'хёрстый', 'мультфильм', 'брейгель', 'мадонна', 'изобразить', 'эскиз', 'зеркало', 'акварель', 'эрмитаж', 'художник', 'импрессионист', 'искусство', 'телескоп', 'студент', 'никас', 'керамика', 'сафронов', 'прикладной', 'полотно', 'репродукция', 'квадрат', 'натюрморт', 'возрождение', 'ван', 'гравюра', 'анатомия', 'справа', 'делиться', 'иллюстратор', 'контраст', 'изобразительный', 'фигура', 'роспись', 'абстрактный', 'аукцион', 'статуя', 'мона', 'художница', 'живописный', 'мрамор', 'левитан', 'пятно', 'выполненный', 'автопортрет', 'святой', 'дама', 'гиперреализм', 'созданный', 'интерьер', 'изображённый', 'костюм', 'полагать', 'скрытый', 'приём', 'скульптурный', 'давид', 'пикассо', 'музей', 'тк', 'ремесло', 'даль', 'создание', 'выложить', 'собрание', 'галерея', 'ценность', 'копировать', 'ирония', 'сейя', 'заказчик', 'мазня', 'разбираться', 'отдыхающий', 'выставляться', 'проводница', 'скрин', 'творческий', 'миниатюра', 'ученик', 'набросок', 'шагать', 'выставка', 'корова', 'характерный', 'расположенный', 'вуз', 'удаваться', 'побережье', 'змея', 'призма', 'исландия', 'образование', 'плакат', 'лиза', 'выбраться', 'изображение', 'нарута', 'микеланджело', 'талант', 'изящный', 'пр', 'академический', 'разместить', 'розовый', 'композиция', 'воображение', 'акула', 'фотография', 'евангелиона', 'посетить', 'ренессанс', 'здание', 'модерн', 'бибоп', 'манера', 'рафаэль', 'нарисовать', 'ритм', 'наруто', 'определить', 'пейзаж', 'туалет', 'зарисовка', 'древний', 'камчатка', 'храниться', 'изображать', 'собор', 'аниме', 'амстердам', 'нижний', 'занятие', 'перспектива', 'увлечение', 'арт', 'ранее', 'туристический', 'тоска', 'тщательно', 'вена', 'ленин', 'творчество', 'сюрреализм', 'хентай', 'воробей', 'культура', 'достоинство', 'гамма', 'дочь', 'поляна', 'винчи', 'мастер', 'картинка', 'дворецкий', 'документ', 'показаться', 'среди', 'леса', 'удаться', 'облако', 'овашка', 'карандаш', 'палитра', 'лёд', 'манга', 'французский', 'контекст', 'век', 'гиас', 'специалист', 'кадр', 'захотеться', 'тонкий', 'ряд', 'подниматься', 'костёр', 'голландский', 'цвет', 'христос', 'кисть', 'синкай', 'влажность', 'академик', 'одежда', 'чей', 'камень', 'напоминать', 'информация', 'школьный', 'старинный', 'нечто', 'современный', 'круиз', 'прекрасный', 'девочка', 'оливковый', 'представлять', 'опенинг', 'материал', 'приходить', 'талантливый', 'японский', 'въезд', 'пересмотреть', 'коллекция', 'соц', 'анимешник', 'сосна', 'старший', 'истинный', 'нота', 'цветок', 'великолепный', 'зацепить', 'фотка', 'температура', 'писать', 'деталь', 'вспомниться', 'авангард', 'блич', 'слева', 'верный', 'повлиять', 'видение', 'завтрак', 'композитор', 'тетрадь', 'печь', 'учитель', 'культурный', 'сухой', 'передавать', 'обнаружить', 'среда', 'средневековье', 'средневековый', 'неизвестный', 'фрагмент', 'пользоваться', 'любоваться', 'сестра', 'научиться', 'утка', 'повседневность', 'немецкий', 'звать', 'википедия', 'палец', 'представление', 'натура', 'зал', 'нежный', 'растение', 'направление', 'рассматривать', 'одновременно', 'сфоткать', 'глаз', 'бумага']

# %%
books_ppmi = {}
for w, contexts in smoothppmi.items():
    books_ppmi[w] = contexts['books']
books_top_threehundred = sorted(books_ppmi, key = books_ppmi.get, reverse=True)[:300]
print(books_top_threehundred)
# Out:
# ['школьный', 'роман', 'кинг', 'верный', 'приём', 'девочка', 'показаться', 'паланик', 'краска', 'дневник', 'зацепить', 'жанр', 'потрясающий', 'классик', 'представлять', 'выбраться', 'литературный', 'созданный', 'экранизация', 'святой', 'ранее', 'прочитать', 'лёд', 'ирония', 'шишкин', 'читатель', 'рассказ', 'эстетика', 'джон', 'палец', 'глаз', 'подойти', 'набоков', 'описанный', 'дама', 'летний', 'подниматься', 'запах', 'добрый', 'сестра', 'уехать', 'номер', 'ценность', 'удаться', 'мастерская', 'писатель', 'отпуск', 'повесть', 'писать', 'сложный', 'надежда', 'домой', 'делиться', 'пересмотреть', 'особо', 'оставить', 'одиночество', 'пр', 'достоинство', 'цена', 'семь', 'стараться', 'змея', 'мультфильм', 'время', 'причём', 'удаваться', 'прочесть', 'манера', 'бесплатно', 'прага', 'современник', 'думать', 'создание', 'издание', 'возраст', 'вопрос', 'эстетический', 'студент', 'страшно', 'снова', 'книга', 'древний', 'туристический', 'приятно', 'полагать', 'властелин', 'чтиво', 'смотреть', 'культура', 'предложение', 'сухой', 'корова', 'мальчик', 'философия', 'картина', 'нечто', 'чей', 'творчество', 'проза', 'захотеться', 'оторваться', 'воображение', 'порой', 'призрак', 'кто', 'десять', 'мёд', 'условие', 'тонкий', 'слог', 'попытка', 'прекрасный', 'читаться', 'программа', 'приходиться', 'путешествие', 'образование', 'талант', 'живопись', 'ехать', 'наблюдать', 'собрание', 'книжный', 'встречаться', 'нормальный', 'среди', 'смерть', 'мочь', 'сон', 'знакомство', 'голливудский', 'героиня', 'язык', 'действительно', 'розовый', 'день', 'старший', 'академик', 'мера', 'звучать', 'мёртвый', 'современный', 'приходить', 'репина', 'рай', 'нежный', 'водиться', 'захватывающий', 'подросток', 'характерный', 'прелесть', 'ученик', 'бежать', 'одновременно', 'именно', 'дочь', 'стекло', 'умный', 'концовка', 'камень', 'сборник', 'талантливый', 'прочтение', 'поделиться', 'эпизод', 'цель', 'информация', 'детектив', 'получить', 'почитать', 'деревня', 'браун', 'младенец', 'повествование', 'винчи', 'творческий', 'остановиться', 'безусловно', 'подробность', 'милый', 'зеркало', 'турция', 'ле', 'ощущение', 'исландия', 'триллер', 'муж', 'композитор', 'потерять', 'великолепный', 'пожалуйста', 'нота', 'пятно', 'скрытый', 'вовсе', 'личность', 'общий', 'американский', 'фантастика', 'тоска', 'воспоминание', 'стивен', 'интрига', 'искать', 'век', 'побережье', 'фраза', 'напоминать', 'туалет', 'разбираться', 'дух', 'близкий', 'очевидный', 'ряд', 'достоевский', 'литература', 'прочитанный', 'фантазия', 'википедия', 'кафка', 'поляна', 'коэльо', 'ждать', 'преступление', 'считать', 'портрет', 'тк', 'толстый', 'желание', 'исторический', 'ван', 'истинный', 'мнение', 'утка', 'посоветовать', 'пользоваться', 'продолжение', 'иллюстрация', 'сутки', 'чудо', 'сказка', 'импрессионизм', 'родитель', 'критика', 'определённый', 'чтение', 'равно', 'результат', 'единственный', 'рембрандт', 'редкий', 'встретить', 'вообще', 'абсолютно', 'контекст', 'ритм', 'пытаться', 'жалко', 'отдыхающий', 'что', 'род', 'назад', 'воробей', 'завтрак', 'выложить', 'представление', 'мировой', 'код', 'изящный', 'начать', 'произведение', 'курица', 'документ', 'пусть', 'шаг', 'содержание', 'вуз', 'копировать', 'поиск', 'достаточно', 'перечитывать', 'касаться', 'цивилизация', 'просто', 'иностранный', 'любопытный', 'тяжёлый', 'ознакомиться', 'кадр', 'акунин', 'изобразить', 'любить', 'бумага', 'интернет', 'помочь', 'дочитать', 'зарисовка', 'обнаружить', 'рельеф']

# %%
films_ppmi = {}
for w, contexts in smoothppmi.items():
    films_ppmi[w] = contexts['films']
films_top_threehundred = sorted(films_ppmi, key = films_ppmi.get, reverse=True)[:300]
print(films_top_threehundred)
# Out:
# ['академик', 'кинг', 'куарон', 'приём', 'ирония', 'терминатор', 'прокат', 'голливудский', 'картина', 'мультфильм', 'властелин', 'жанр', 'кассовый', 'семь', 'ценность', 'роман', 'поляна', 'пересмотреть', 'созданный', 'верный', 'лида', 'экранизация', 'прогноз', 'номинация', 'читатель', 'краска', 'чтиво', 'смотреть', 'подниматься', 'ранее', 'литературный', 'дневник', 'кинотеатр', 'фильм', 'эстетический', 'костюм', 'классик', 'номер', 'школьный', 'джон', 'исландия', 'иностранный', 'эстетика', 'повлиять', 'кина', 'малек', 'творческий', 'создание', 'критика', 'купер', 'опрос', 'показаться', 'культура', 'зеркало', 'съёмка', 'вопрос', 'студия', 'палец', 'вайс', 'критерий', 'представлять', 'полагать', 'девочка', 'полнометражный', 'святой', 'кадр', 'стараться', 'копировать', 'живопись', 'матрица', 'титаник', 'клоуз', 'пр', 'унесённый', 'среди', 'особо', 'бафта', 'глаз', 'оставить', 'голосовать', 'талант', 'писатель', 'условие', 'думать', 'паланик', 'гага', 'надежда', 'просмотр', 'зацепить', 'получить', 'студент', 'кубрик', 'причём', 'лента', 'режиссёрский', 'арт', 'оскар', 'скрытый', 'вк', 'кто', 'сша', 'крестный', 'летний', 'объективный', 'подойти', 'образование', 'критик', 'сложный', 'чей', 'писать', 'очевидный', 'время', 'достоинство', 'книга', 'ансамбль', 'американский', 'талантливый', 'современник', 'триллер', 'потрясающий', 'номинант', 'режиссура', 'шиндлер', 'глобус', 'десять', 'попытка', 'добрый', 'рапсодия', 'номинировать', 'шишкин', 'удаться', 'предложение', 'нормальный', 'искусство', 'мнение', 'дама', 'уехать', 'утка', 'композитор', 'мастерская', 'считать', 'кинематограф', 'описанный', 'делиться', 'мировой', 'результат', 'безусловно', 'исторический', 'форум', 'монтаж', 'аргумент', 'наблюдать', 'философия', 'снять', 'прочитать', 'именно', 'гильдия', 'мочь', 'массовый', 'камчатка', 'проголосовать', 'определить', 'возраст', 'повесть', 'пусть', 'режиссёр', 'одновременно', 'драма', 'рассказ', 'выбор', 'мальчик', 'шедевр', 'действительно', 'сценарист', 'мера', 'лёд', 'старший', 'корова', 'комедия', 'актриса', 'сниматься', 'тонкий', 'снова', 'щас', 'одиночество', 'запах', 'определённый', 'набоков', 'кино', 'равно', 'против', 'кольцо', 'современный', 'камера', 'цель', 'заслуживать', 'удаваться', 'актёр', 'манера', 'фаворитка', 'змея', 'дженкинс', 'репина', 'домой', 'художественный', 'туристический', 'рельеф', 'категория', 'лф', 'спецэффект', 'йорк', 'характерный', 'мёд', 'номинашка', 'раздача', 'актёрский', 'колман', 'найтись', 'пересматривать', 'саба', 'музыкальный', 'голливуд', 'киноиндустрия', 'список', 'википедия', 'программа', 'фантастика', 'представление', 'нечто', 'нота', 'сказка', 'ряд', 'вовсе', 'рембрандт', 'сага', 'учитывать', 'страна', 'пантера', 'прекрасный', 'аниме', 'советский', 'бесплатно', 'считаться', 'голосование', 'древний', 'спорить', 'умный', 'достаточно', 'рисовальщик', 'творчество', 'день', 'тема', 'академия', 'взять', 'абсолютно', 'существовать', 'наиболее', 'розовый', 'единственный', 'авторский', 'воображение', 'контекст', 'сценарий', 'выбраться', 'истинный', 'документ', 'сестра', 'очевидно', 'культурный', 'ссср', 'кп', 'вуз', 'младенец', 'сбор', 'ответить', 'криминальный', 'тематика', 'литература', 'приятно', 'приходить', 'откуда', 'остановиться', 'изобразить', 'дюрер', 'что', 'получать', 'влияние', 'приходиться', 'подросток', 'век', 'сейя', 'импрессионизм', 'направление', 'страшно', 'звучать', 'научиться', 'включить', 'зритель', 'ван', 'пользоваться']

# %%
food_ppmi = {}
for w, contexts in smoothppmi.items():
    food_ppmi[w] = contexts['food']
food_top_threehundred = sorted(food_ppmi, key = food_ppmi.get, reverse=True)[:300]
print(food_top_threehundred)
# Out:
# ['мёд', 'корова', 'сыр', 'курица', 'запах', 'холодильник', 'макароны', 'рис', 'духовка', 'овощ', 'лёд', 'соус', 'сухой', 'ашан', 'вегетарианец', 'пирожок', 'приём', 'сковородка', 'оливковый', 'кабачок', 'пр', 'гречка', 'добавка', 'суп', 'варить', 'тк', 'гриб', 'печь', 'утка', 'нежный', 'школьный', 'домой', 'завтрак', 'питаться', 'масло', 'цена', 'девочка', 'замороженный', 'молоко', 'варение', 'деревня', 'килограмм', 'тесто', 'пицца', 'фарш', 'блюдо', 'смесь', 'химия', 'вкусовой', 'представлять', 'торт', 'стараться', 'температура', 'ресторан', 'святой', 'утро', 'молочный', 'тонкий', 'уксус', 'подойти', 'майонез', 'вода', 'суша', 'помидор', 'ингредиент', 'кефир', 'верный', 'употреблять', 'приправа', 'муж', 'вкусный', 'белок', 'условие', 'краска', 'здоровый', 'аппетит', 'академик', 'чеснок', 'бульон', 'творог', 'выпечка', 'сварить', 'морковь', 'картошка', 'захотеться', 'пирог', 'голод', 'палец', 'вред', 'делиться', 'ужин', 'плавать', 'приготовить', 'подниматься', 'супермаркет', 'голодный', 'сутки', 'ценность', 'кусочек', 'салат', 'сестра', 'нормальный', 'стол', 'особо', 'пища', 'тарелка', 'день', 'дама', 'готовить', 'удаваться', 'витамин', 'глаз', 'есть', 'углевод', 'выложить', 'кинг', 'чай', 'жирный', 'капуста', 'показаться', 'шишкин', 'мультиварка', 'сметана', 'эстетика', 'перец', 'натуральный', 'здоровье', 'отпуск', 'желудок', 'растительный', 'приготовление', 'сорт', 'гадость', 'варёный', 'созданный', 'рецепт', 'приходиться', 'причём', 'начинка', 'зелень', 'куриный', 'вопрос', 'ехать', 'производство', 'время', 'тщательно', 'борщ', 'водиться', 'холодный', 'сахар', 'ирония', 'сало', 'семь', 'куарон', 'шоколад', 'диета', 'пюре', 'думать', 'ранее', 'уехать', 'сладкий', 'возраст', 'фрукт', 'храниться', 'прочитать', 'наблюдать', 'родитель', 'культура', 'мочь', 'поделиться', 'туалет', 'мера', 'поесть', 'лук', 'выбраться', 'прага', 'приходить', 'научиться', 'банка', 'младенец', 'описанный', 'писать', 'нечто', 'дача', 'орех', 'смотреть', 'использовать', 'отдыхающий', 'порой', 'фотка', 'сон', 'запекать', 'вкусно', 'воробей', 'котлета', 'мясо', 'древний', 'рельеф', 'оставить', 'бесплатно', 'страшно', 'потрясающий', 'тыква', 'образование', 'рыба', 'добавлять', 'жарить', 'яйцо', 'туристический', 'прокат', 'исландия', 'магазинный', 'вкус', 'встречаться', 'гр', 'кто', 'солёный', 'баранина', 'читатель', 'добрый', 'леса', 'змея', 'хлеб', 'сложный', 'классик', 'пельмень', 'кастрюля', 'мастерская', 'студент', 'готовка', 'каша', 'вредный', 'мелко', 'приятно', 'порция', 'любить', 'пересмотреть', 'бабушка', 'стекло', 'животное', 'мука', 'мальчик', 'растение', 'паланик', 'всякий', 'именно', 'шашлык', 'равно', 'прелесть', 'испанский', 'оч', 'огурец', 'регион', 'кафе', 'мак', 'организм', 'соевый', 'огород', 'удаться', 'вес', 'летний', 'надежда', 'вещество', 'рацион', 'специя', 'горячий', 'колбаса', 'соль', 'номер', 'рассказ', 'напиток', 'занятие', 'жареный', 'поляна', 'действительно', 'домашний', 'вообще', 'кусок', 'чистый', 'говядина', 'свинина', 'пользоваться', 'десять', 'йогурт', 'упаковка', 'кушать', 'класть', 'ложка', 'толстый', 'одновременно', 'камень', 'снова', 'бежать', 'голливудский', 'копчёный', 'чей', 'откуда', 'розовый', 'семя', 'еда']

# %%
football_ppmi = {}
for w, contexts in smoothppmi.items():
    football_ppmi[w] = contexts['football']
football_top_threehundred = sorted(football_ppmi, key = football_ppmi.get, reverse=True)[:300]
print(football_top_threehundred)
# Out:
# ['лч', 'уефа', 'уехать', 'летний', 'верный', 'турция', 'святой', 'номер', 'представлять', 'роман', 'шишкин', 'ранее', 'приём', 'ехать', 'выбраться', 'исландия', 'мёд', 'подойти', 'цена', 'палец', 'ле', 'показаться', 'надежда', 'ван', 'эстетика', 'смотреть', 'потрясающий', 'испанский', 'девочка', 'корова', 'забить', 'барс', 'травма', 'созданный', 'подниматься', 'шахтёр', 'стараться', 'нормальный', 'глаз', 'результат', 'особо', 'оставить', 'утка', 'мяч', 'удаться', 'думать', 'причём', 'домой', 'португалия', 'пересмотреть', 'снова', 'краска', 'контракт', 'чм', 'зацепить', 'отпуск', 'школьный', 'испанец', 'кто', 'наблюдать', 'приятно', 'условие', 'сухой', 'футбол', 'бразилия', 'ирония', 'время', 'атлетико', 'прогноз', 'вопрос', 'проигрывать', 'талант', 'бесплатно', 'молодец', 'продать', 'сыр', 'евро', 'потерять', 'лёд', 'получить', 'бежать', 'пенальти', 'кинг', 'сложный', 'семь', 'предложение', 'против', 'джон', 'еврокубок', 'тренер', 'макароны', 'мочь', 'пусть', 'ребята', 'мальчик', 'академик', 'игрок', 'юве', 'реал', 'курица', 'десять', 'мы', 'писать', 'возраст', 'чудо', 'делиться', 'запах', 'добрый', 'милан', 'талантливый', 'нап', 'вратарь', 'конкурент', 'футбольный', 'рис', 'равно', 'страшно', 'ждать', 'пр', 'итальянец', 'чей', 'удаваться', 'сборная', 'приходиться', 'спорить', 'дама', 'среди', 'жалко', 'заслуживать', 'кина', 'приходить', 'картина', 'рубин', 'именно', 'испания', 'день', 'очевидный', 'действительно', 'эстетический', 'обидный', 'прочитать', 'манера', 'фотка', 'прошлый', 'выигрывать', 'леонардо', 'считать', 'заслужить', 'классик', 'мера', 'давид', 'эпизод', 'прага', 'англия', 'кризис', 'болеть', 'достоинство', 'камень', 'чемпион', 'создание', 'специалист', 'выложить', 'щас', 'сестра', 'поляна', 'сити', 'иностранный', 'вообще', 'ы', 'справа', 'взять', 'нападающий', 'кадр', 'концовка', 'россия', 'попытка', 'германий', 'голландец', 'пас', 'лидер', 'ряд', 'играть', 'великолепный', 'учитывать', 'разбираться', 'страна', 'вчера', 'немецкий', 'уйти', 'единственный', 'зарплата', 'перспектива', 'штрафной', 'тура', 'прекрасный', 'просто', 'полуфинал', 'повод', 'научиться', 'получать', 'духовка', 'кубок', 'объективный', 'интер', 'туристический', 'воробей', 'нечто', 'остаться', 'полагать', 'наш', 'холодильник', 'помочь', 'среда', 'случай', 'безусловно', 'порой', 'утро', 'информация', 'хотеть', 'желание', 'голландия', 'назад', 'начать', 'форма', 'ценность', 'убогий', 'овощ', 'поехать', 'соус', 'выступать', 'гол', 'поражение', 'даль', 'зря', 'аргумент', 'слабый', 'родной', 'забивать', 'шаг', 'допустить', 'одновременно', 'сезон', 'интрига', 'цель', 'абсолютно', 'прошлое', 'счёт', 'обыграть', 'повезти', 'никакой', 'лига', 'передача', 'положение', 'оба', 'ливерпуль', 'касаться', 'сила', 'посадить', 'повлиять', 'звучать', 'симпатичный', 'зенит', 'мнение', 'вряд', 'звать', 'вовсе', 'откуда', 'мастерская', 'динамо', 'судья', 'считаться', 'встречаться', 'умный', 'что', 'представить', 'достаточно', 'впереди', 'масло', 'защитник', 'удача', 'мировой', 'водиться', 'красивый', 'осень', 'истинный', 'общий', 'шанс', 'гость', 'фанат', 'возможно', 'старший', 'арсенал', 'отлично', 'ходить', 'голландский', 'фланг', 'ясно', 'чехия', 'дневник', 'мёртвый']

# %%
games_ppmi = {}
for w, contexts in smoothppmi.items():
    games_ppmi[w] = contexts['games']
games_top_threehundred = sorted(games_ppmi, key = games_ppmi.get, reverse=True)[:300]
print(games_top_threehundred)
# Out:
# ['жанр', 'приём', 'представлять', 'верный', 'мультиплеер', 'палец', 'цена', 'ранее', 'глаз', 'созданный', 'халф', 'летний', 'нормальный', 'роман', 'зацепить', 'показаться', 'святой', 'подойти', 'особо', 'сложный', 'лч', 'девочка', 'смотреть', 'подниматься', 'школьный', 'потрясающий', 'корова', 'краска', 'причём', 'выбраться', 'надежда', 'бесплатно', 'стелс', 'оставить', 'консольный', 'стараться', 'уехать', 'думать', 'снова', 'номер', 'удаться', 'бежать', 'кинг', 'время', 'лёд', 'студия', 'забить', 'кто', 'ехать', 'пересмотреть', 'ле', 'костюм', 'вопрос', 'семь', 'писать', 'результат', 'ирония', 'условие', 'добрый', 'создание', 'поиграть', 'ждать', 'убогий', 'получить', 'наблюдать', 'приходиться', 'эстетика', 'десять', 'щас', 'кризис', 'приятно', 'мочь', 'классик', 'код', 'продать', 'мёд', 'эпизод', 'физика', 'кадр', 'мяч', 'терминатор', 'дневник', 'экранизация', 'утка', 'равно', 'древний', 'прочитать', 'потерять', 'геймплей', 'достоинство', 'деревня', 'страшно', 'среди', 'именно', 'очевидный', 'против', 'ценность', 'сыр', 'пусть', 'делиться', 'концовка', 'травма', 'попытка', 'мера', 'конкурент', 'спорить', 'футбол', 'день', 'джон', 'домой', 'арт', 'игрок', 'проигрывать', 'нечто', 'разбираться', 'голливудский', 'камень', 'действительно', 'курица', 'ван', 'мастерская', 'пр', 'молодец', 'вообще', 'одновременно', 'картина', 'прекрасный', 'возраст', 'картинка', 'полагать', 'считать', 'учитывать', 'нарисованный', 'ребята', 'цель', 'фпс', 'ряд', 'контракт', 'издание', 'играть', 'предложение', 'просто', 'порой', 'камера', 'единственный', 'приходить', 'выбор', 'сухой', 'чей', 'летать', 'никакой', 'боевой', 'дама', 'реал', 'уефа', 'добавка', 'нету', 'копировать', 'отпуск', 'властелин', 'взять', 'мёртвый', 'чудо', 'красивый', 'аргумент', 'прогноз', 'стекло', 'реально', 'чм', 'великолепный', 'говно', 'запах', 'описанный', 'барс', 'сингл', 'захотеться', 'мы', 'встречаться', 'откуда', 'жалко', 'сестра', 'баг', 'умный', 'тонкий', 'цветовой', 'гта', 'определённый', 'цифра', 'получать', 'всякий', 'научиться', 'сутки', 'мультфильм', 'босс', 'ощущение', 'ствол', 'шаг', 'пользоваться', 'бесплатный', 'огромный', 'холодильник', 'удаваться', 'литературный', 'очевидно', 'общий', 'допустить', 'мальчик', 'объективный', 'онлайн', 'продолжение', 'бокс', 'достаточно', 'мнение', 'скрин', 'выложить', 'рассказ', 'академик', 'талант', 'информация', 'заслуживать', 'абсолютно', 'вовсе', 'начать', 'случай', 'форум', 'редкий', 'назад', 'желание', 'студент', 'плавать', 'прошлый', 'управление', 'что', 'пытаться', 'вегас', 'гораздо', 'вайс', 'смерть', 'кассовый', 'пирожок', 'фанат', 'стол', 'часть', 'саба', 'прикольный', 'использовать', 'отлично', 'смесь', 'шедевр', 'том', 'скрытый', 'тренер', 'кина', 'фотка', 'хотеть', 'соня', 'эстетический', 'такси', 'полностью', 'чо', 'звучать', 'наоборот', 'ясно', 'мелодия', 'прокат', 'шутеры', 'современный', 'здание', 'обидный', 'повод', 'шишкин', 'прелесть', 'зеркало', 'напоминать', 'продажа', 'дык', 'масса', 'помочь', 'город', 'повлиять', 'прага', 'ходячий', 'искать', 'близкий', 'замечать', 'остаться', 'сити', 'дух', 'кнопка', 'поляна', 'считаться', 'вода', 'тень', 'возможно', 'зря', 'такой', 'змея', 'талантливый', 'ходить', 'сша']

# %%
music_ppmi = {}
for w, contexts in smoothppmi.items():
    music_ppmi[w] = contexts['music']
music_top_threehundred = sorted(music_ppmi, key = music_ppmi.get, reverse=True)[:300]
print(music_top_threehundred)
# Out:
# ['жанр', 'мелодия', 'вокалист', 'сложный', 'музыкальный', 'классик', 'потрясающий', 'девочка', 'зацепить', 'нормальный', 'особо', 'время', 'композитор', 'ранее', 'думать', 'звучать', 'нота', 'смотреть', 'гитара', 'представлять', 'причём', 'ребята', 'показаться', 'кто', 'студия', 'снова', 'гитарист', 'писать', 'добрый', 'номер', 'приятно', 'летний', 'мочь', 'джон', 'стараться', 'вопрос', 'палец', 'удаться', 'глаз', 'дуэт', 'оставить', 'верный', 'именно', 'ждать', 'играть', 'талантливый', 'порой', 'щас', 'сингл', 'приём', 'действительно', 'кавер', 'творчество', 'спорить', 'школьный', 'джазовый', 'считать', 'талант', 'равно', 'мера', 'вообще', 'созданный', 'получить', 'пр', 'подойти', 'нечто', 'пусть', 'чей', 'разбираться', 'среди', 'просто', 'ритм', 'результат', 'слышать', 'создание', 'тяжёлый', 'ван', 'великолепный', 'манера', 'десять', 'надежда', 'испанский', 'эстетика', 'молодец', 'против', 'поиграть', 'смесь', 'возраст', 'единственный', 'мнение', 'мальчик', 'образование', 'арт', 'день', 'направление', 'пересмотреть', 'забить', 'потерять', 'общий', 'очевидный', 'приходиться', 'композиция', 'взять', 'ряд', 'выложить', 'прекрасный', 'творческий', 'современный', 'прочитать', 'консольный', 'приходить', 'начать', 'нету', 'определённый', 'кинг', 'издание', 'ирония', 'шедевр', 'прикольный', 'одновременно', 'фанат', 'домой', 'святой', 'песня', 'никакой', 'культура', 'костюм', 'делиться', 'мадонна', 'красивый', 'абсолютно', 'назад', 'искать', 'редкий', 'форум', 'научиться', 'информация', 'всякий', 'напоминать', 'вовсе', 'условие', 'попёс', 'пластинка', 'полагать', 'выступать', 'достаточно', 'весёлый', 'что', 'древний', 'оч', 'полностью', 'релиз', 'повод', 'том', 'достоинство', 'критика', 'халф', 'дух', 'умный', 'любить', 'давно', 'кризис', 'мёртвый', 'допустить', 'отлично', 'истинный', 'пытаться', 'учитывать', 'такой', 'видео', 'нежный', 'возможно', 'сестра', 'почему', 'муза', 'ценность', 'фильм', 'использовать', 'ы', 'хотеть', 'откуда', 'страшно', 'реально', 'зря', 'сборник', 'захотеться', 'бежать', 'похожий', 'случай', 'немецкий', 'роман', 'коллектив', 'чистый', 'мы', 'босс', 'концовка', 'убогий', 'дама', 'близкий', 'масса', 'эпизод', 'стелс', 'говно', 'мировой', 'попытка', 'уйти', 'являться', 'картинка', 'наоборот', 'считаться', 'американский', 'лишь', 'клип', 'касаться', 'характерный', 'желание', 'помочь', 'гораздо', 'обидный', 'мультиплеер', 'поп', 'кадр', 'жалко', 'решить', 'часть', 'поделиться', 'остаться', 'краска', 'музыкант', 'бесплатно', 'картина', 'товарищ', 'огромный', 'копировать', 'чудо', 'знакомство', 'прелесть', 'прошлый', 'семь', 'отдельный', 'просмотр', 'бас', 'трек', 'оба', 'википедия', 'тема', 'выбор', 'существовать', 'заслуживать', 'сильно', 'прошлое', 'гта', 'лёгкий', 'курица', 'ответить', 'ясно', 'вместе', 'ощущение', 'остальной', 'продолжение', 'альтернатива', 'тонкий', 'род', 'порадовать', 'продажа', 'контракт', 'слабый', 'представить', 'смерть', 'гармония', 'пользоваться', 'живой', 'блэк', 'важный', 'прям', 'создать', 'вчера', 'группа', 'фраза', 'практически', 'многий', 'целое', 'смысл', 'простой', 'пожалуйста', 'похоже', 'повлиять', 'наверное', 'номинация', 'старший', 'кстати', 'электроника', 'рука', 'личность', 'рэп', 'плохой', 'хоп', 'прийти', 'интернет', 'миллион']

# %%
nature_ppmi = {}
for w, contexts in smoothppmi.items():
    nature_ppmi[w] = contexts['nature']
nature_top_threehundred = sorted(nature_ppmi, key = nature_ppmi.get, reverse=True)[:300]
print(nature_top_threehundred)
# Out:
# ['дерево', 'песня', 'альбом', 'синица', 'видео', 'ворона', 'дятел', 'растение', 'птичка', 'птица', 'лес', 'цвести', 'гриб', 'сосна', 'ствол', 'вчера', 'снег', 'цветок', 'цветочек', 'лесной', 'ягода', 'речка', 'песнь', 'музыкант', 'мышь', 'заснять', 'рок', 'просека', 'крыса', 'вблизи', 'фотка', 'ютуба', 'слушать', 'осень', 'клип', 'трава', 'наблюдать', 'сфоткать', 'хищник', 'ветка', 'крик', 'осенний', 'дуб', 'мороз', 'тема', 'природа', 'расти', 'кормушка', 'снимок', 'играть', 'музыкальный', 'голубь', 'листва', 'металл', 'группа', 'ёлка', 'гитара', 'огород', 'костёр', 'песенка', 'весна', 'вода', 'животное', 'провод', 'шишка', 'лист', 'фотик', 'деревце', 'лиса', 'кадр', 'среди', 'хвост', 'слышать', 'небо', 'сад', 'занести', 'охотиться', 'заросль', 'метать', 'человеческий', 'фото', 'фоткать', 'куст', 'вокал', 'похоже', 'живой', 'бас', 'голос', 'коллектив', 'болото', 'композиция', 'видно', 'семя', 'такой', 'ворон', 'воробей', 'охота', 'хит', 'музыка', 'гармония', 'рука', 'птенец', 'запись', 'солёный', 'жёлтый', 'наверно', 'холм', 'посадить', 'прошлый', 'похожий', 'мочь', 'качество', 'хоп', 'глаз', 'водиться', 'выглядеть', 'семечко', 'след', 'петь', 'пища', 'трек', 'панк', 'телефон', 'зимний', 'время', 'весенний', 'реал', 'комар', 'змея', 'блэк', 'звук', 'случайно', 'туча', 'кнопка', 'дабстеп', 'встречаться', 'щас', 'исполнитель', 'облако', 'цветущий', 'падать', 'кстати', 'картинка', 'жаль', 'игра', 'пусть', 'кошка', 'пытаться', 'хип', 'вверх', 'кот', 'вон', 'способ', 'гнездо', 'мёртвый', 'столб', 'декоративный', 'красивый', 'вид', 'джаз', 'мелодичный', 'зима', 'ух', 'парк', 'ролик', 'соня', 'выступление', 'тёмный', 'попёс', 'название', 'проект', 'появляться', 'послушать', 'существо', 'справа', 'леса', 'ряд', 'куча', 'услышать', 'инструмент', 'горизонт', 'часто', 'муза', 'прийти', 'получиться', 'дело', 'лишь', 'окно', 'бежать', 'прям', 'увидеть', 'голова', 'тень', 'домашний', 'звучание', '…', 'почему', 'попасться', 'символ', 'жалко', 'собрать', 'ссылка', 'писать', 'зверь', 'настройка', 'думать', 'свежий', 'собака', 'сегодня', 'концерт', 'просто', 'цивилизация', 'нежный', 'съёмка', 'тк', 'детство', 'лежать', 'вообще', 'помнить', 'последний', 'связь', 'впервые', 'белый', 'туман', 'камера', 'радовать', 'упасть', 'среда', 'материал', 'сухой', 'казаться', 'обнаружить', 'википедия', 'организм', 'близкий', 'наступить', 'местность', 'поздний', 'необычно', 'зелёный', 'певица', 'частый', 'действительно', 'должный', 'сырой', 'точно', 'поле', 'отлично', 'создать', 'сидеть', 'настроение', 'страх', 'всякий', 'естественный', 'попадаться', 'голый', 'пейзаж', 'творчество', 'медведь', 'ох', 'сделать', 'голубой', 'пластинка', 'добавить', 'любоваться', 'чудо', 'закат', 'наоборот', 'целый', 'ваш', 'поход', 'техника', 'издалёка', 'купаться', 'пятно', 'зелень', 'слух', 'роль', 'розовый', 'мелкий', 'уход', 'шаг', 'видный', 'река', 'метр', 'скрин', 'разговор', 'прикольный', 'вроде', 'мусор', 'назад', 'жрать', 'спросить', 'форма', 'плата', 'ухо', 'сорт', 'создавать', 'плохой', 'глубина']

# %%
travel_ppmi = {}
for w, contexts in smoothppmi.items():
    travel_ppmi[w] = contexts['travel']
travel_top_threehundred = sorted(travel_ppmi, key = travel_ppmi.get, reverse=True)[:300]
print(travel_top_threehundred)
# Out:
# ['турция', 'ехать', 'цена', 'время', 'думать', 'день', 'мочь', 'смотреть', 'вообще', 'просто', 'фотка', 'кто', 'евро', 'красивый', 'номер', 'именно', 'прага', 'город', 'равно', 'страна', 'мы', 'хотеть', 'летать', 'вопрос', 'нормальный', 'путешествие', 'глаз', 'поехать', 'ряд', 'причём', 'такой', 'вода', 'ждать', 'особо', 'побережье', 'виза', 'назад', 'посетить', 'писать', 'никакой', 'огромный', 'всякий', 'туризм', 'туристический', 'взять', 'общий', 'прекрасный', 'чистый', 'отпуск', 'ходить', 'любить', 'отдыхать', 'действительно', 'том', 'считать', 'тура', 'испания', 'утро', 'турист', 'случай', 'прошлый', 'рассказ', 'ресторан', 'такси', 'египет', 'часть', 'слышать', 'почему', 'получить', 'милан', 'реально', 'наш', 'въезд', 'единственный', 'приходиться', 'везде', 'бразилия', 'удаться', 'здание', 'самый', 'россия', 'маршрут', 'гостиница', 'снова', 'завтрак', 'желание', 'кстати', 'сильно', 'парк', 'многий', 'точно', 'культура', 'начать', 'остаться', 'домой', 'искать', 'мера', 'мой', 'ощущение', 'камчатка', 'показаться', 'решить', 'вид', 'самолёт', 'играть', 'наверное', 'дом', 'сидеть', 'англия', 'плавать', 'сторона', 'выбор', 'деревня', 'гораздо', 'направление', 'оставить', 'год', 'близкий', 'приятно', 'знать', 'погода', 'съездить', 'исландия', 'дама', 'рука', 'южный', 'холодный', 'ночь', 'курорт', 'дорогой', 'достаточно', 'правда', 'среди', 'похожий', 'понимать', 'язык', 'говорить', 'испанец', 'давно', 'зима', 'германий', 'возможно', 'брать', 'сша', 'пройти', 'итальянец', 'главный', 'дешёвый', 'бесплатный', 'смысл', 'лишь', 'приехать', 'представлять', 'уехать', 'условие', 'шенген', 'сутки', 'остальной', 'сам', 'осень', 'фильм', 'дело', 'отдыхающий', 'пляж', 'мир', 'пусть', 'должный', 'потрясающий', 'чехия', 'прям', 'встретить', 'тема', 'откуда', 'туда', 'поэтому', 'остановиться', 'абсолютно', 'экскурсия', 'простой', 'дать', 'выходить', 'парка', 'каждый', 'захотеться', 'регион', 'камень', 'жить', 'группа', 'повод', 'вкусный', 'помочь', 'место', 'нечто', 'родитель', 'родной', 'пытаться', 'повезти', 'ужин', 'практически', 'получать', 'москва', 'ты', 'воздух', 'запах', 'число', 'цель', 'сначала', 'ребята', 'снег', 'летний', 'улица', 'далее', 'иметь', 'палец', 'добрый', 'насколько', 'подумать', 'кафе', 'другой', 'это', 'форум', 'проблема', 'сила', 'полно', 'учитывать', 'сколько', 'прямо', 'улочка', 'особенно', 'древний', 'муж', 'любитель', 'городок', 'скучно', 'стол', 'спокойный', 'счёт', 'выглядеть', 'климат', 'бесплатно', 'побывать', 'подойти', 'уйти', 'собор', 'туалет', 'оттуда', 'подниматься', 'наоборот', 'таиланд', 'круиз', 'деньга', 'тыща', 'увидеть', 'температура', 'хватить', 'который', 'погулять', 'расположенный', 'стараться', 'важный', 'вдоль', 'август', 'касаться', 'оба', 'небольшой', 'доллар', 'футбол', 'рейс', 'страшно', 'живой', 'прогулка', 'включённый', 'казаться', 'возможность', 'чудо', 'прелесть', 'справка', 'отдельный', 'расстояние', 'край', 'юг', 'дух', 'рубль', 'плохо', 'настолько', 'долго', 'прийтись', 'мост', 'добираться', 'настоящий', 'чувствовать', 'дерево', 'плюс', 'июль', 'мечта', 'ребёнок', 'жизнь', 'предложение', 'конец', 'тот']

# %%
topthreehundred = {}

# %%
for i in categs:
    topthreehundred[i] = eval(i + '_top_threehundred')

# %%
with open('top_threehundred_ppmi.pkl', 'wb') as tp:
    pkl.dump(topthreehundred, tp)
tp.close()
