# %%
import pickle as pkl
import math
from tqdm import tqdm

# %%
with open('Tris Absolute Add2 Lessthan0.005.pkl', 'rb') as m2:
    with_smoothing = pkl.load(m2)
m2.close()

# %%
def p_wc(word, context_word, counts, total_counts):
    return counts[word][context_word] / total_counts

# %%
def p_w(word, counts, total_counts):
    return sum(counts[word].values()) / total_counts

# %%
def p_c(context_word, counts, total_counts):
    return sum(freqs.get(context_word, 0) for freqs in counts.values()) / total_counts

# %%
def pmi(word, context_word, counts, total_counts):
    ans = (p_wc(word, context_word, counts, total_counts) /
          (p_w(word, counts, total_counts) * p_c(context_word, counts, total_counts)))
    if ans:
        return math.log2(ans)
    else:
        return 0

# %%
def ppmi(word, context_word, counts, total_counts):
    ans = pmi(word, context_word, counts, total_counts)
    return ans if ans > 0 else 0

# %%
def get_total_counts(counts):
    """counts is a dict of dicts"""
    return sum([sum(vals.values()) for vals in counts.values()])

# %%
def build_matrix(counts):
    total_counts = get_total_counts(counts)
    total_words = len(counts)
    print('working out PPMI')
    for w, contexts in tqdm(counts.items()):
        for c in contexts:
            counts[w][c] = ppmi(w, c, counts, total_counts)
    print('done with PPMI')
    return counts

# %%
smoothppmi = build_matrix(with_smoothing)
# Out:
# working out PPMI
# 100%|██████████████████████████████████████| 6647/6647 [01:37<00:00, 68.51it/s]
# done with PPMI

# %%
with open('Tri PPMIs Add-2 0.005.pkl', 'wb') as p1:
    pkl.dump(smoothppmi, p1)
p1.close()

# %%
def rank_words(counts):
    mean_ppmi = {}
    top_ppmi = {}
    for w, contexts in counts.items():
        vals = list(contexts.values())
        mean_ppmi[w] = sum(vals) / len(vals)
        top_ppmi[w] = max(vals)
    order_mean = sorted(mean_ppmi, key=mean_ppmi.get, reverse=True)
    order_top = sorted(top_ppmi, key=top_ppmi.get, reverse=True)
  #  print(order_mean, file=open('words by mean ppmi no lem.txt', 'w', encoding='utf-8'))
  #  print(order_top, file=open('words by top ppmi no lem.txt', 'w', encoding='utf-8'))
    return order_top

# %%
categs = ['anime', 'art', 'books', 'films', 'food', 'football', 'games', 'music', 'nature', 'travel']

# %%
anime_ppmi = {}
for w, contexts in smoothppmi.items():
    anime_ppmi[w] = contexts['anime']
anime_top_threehundred = sorted(anime_ppmi, key = anime_ppmi.get, reverse=True)[:300]
print(anime_top_threehundred)
# Out:
# ['гиа', 'ядз', 'мув', 'адь', 'иас', 'кэн', 'дб ', 'мур', 'дте', 'жба', ' оя', 'кик', 'бля', 'урд', 'имд', 'вящ', 'ару', 'яша', 'смо', 'дсн', 'ы ж', 'баи', 'отз', 'улы', ' ям', 'зг ', 'умч', 'ячи', 'зиа', 'ярк', 'х и', 'онг', 'доф', ' ха', 'ухт', 'кен', 'кая', 'упо', 'окг', 'ляч', 'хая', 'одб', 'т ю', ' рю', 'и э', 'ячо', 'рье', 'изр', 'имэ', 'цки', 'кше', 'ног', 'удз', 'иву', 'хел', 'к ф', ' об', 'или', 'мие', ' уж', 'ант', 'атл', 'тюд', 'окт', 'ейя', 'нев', 'мед', 'ост', 'евн', 'бое', 'ауч', 'я я', 'чие', 'эст', 'у о', 'цан', 'рив', 'л т', 'шат', 'тпа', ' ам', 'лое', 'яст', 'з г', 'е г', 'лол', 'тби', 'юра', 'в ф', ' ол', 'о м', 'ц е', 'реф', 'сей', 'вме', 'еща', 'ени', 'тез', 'ане', 'вбо', 'чиц', 'эйф', 'кат', 'зе ', 'чон', 'икл', 'йле', 'ные', 'узн', 'пущ', 'лих', ' мэ', 'оит', 'к ц', 'р д', 'кну', 'удр', 'к я', 'орж', 'зм ', 'енэ', 'ыня', ' хм', 'э к', 'юр ', 'лиш', 'вкл', 'идц', 'ияд', 'сай', 'имс', 'убо', 'овс', 'ены', 'едз', 'рес', 'ндз', 'оче', 'июк', 'изо', 'йло', 'чюр', 'тло', 'кем', 'бэ ', 'зым', 'овл', 'юча', 'шаф', 'яму', 'езн', 'дя ', ' зм', 'гед', 'пиц', 'ках', 'зыс', 'тву', 'жда', 'мэй', 'схв', 'дип', 'мум', 'н в', ' бю', 'анп', 'слу', 'ери', ' дл', 'тфи', 'янд', 'цин', 'фэн', 'мор', 'вам', ' яо', 'ажк', 'ьту', 'яой', 'бир', 'пет', 'ьтф', 'яса', 'ацу', 'реб', ' пх', 'эдз', 'идз', ' дз', 'еуб', 'снь', 'сфе', 'юки', 'ныш', 'окл', 'ейв', 'рем', 'сри', 'туш', 'кле', ' ° ', 'тат', 'клы', 'урб', ' сш', ' ак', 'э т', 'хоу', 'экш', 'хну', 'ающ', 'одв', 'ыво', 'вгу', 'ати', 'щее', ' пр', 'щни', 'ж о', ' шк', 'спи', 'м з', 'нэн', 'ьеф', ' гэ', 'поп', 'ача', 'кию', 'циф', 'пху', 'осм', 'ека', 'бли', 'хик', 'гап', 'ващ', 'гив', 'азг', 'нга', 'моэ', 'щиц', 'оин', 'наж', 'тну', 'мст', 'тзы', 'р о', 'нро', 'сэй', 'ьфи', 'т я', 'ояш', 'даи', 'заш', 'биб', 'зук', 'тв ', 'уин', 'лзе', 'окр', 'лах', 'атр', 'вце', 'е е', 'нее', 'лхи', 'сау', 'инг', 'мпу', 'уси', 'гки', 'аля', 'чны', 'опл', 'хос', 'гуш', 'ств', 'нем', 'г у', 'хае', 'сси', 'нхо', ' лл', ' ож', 'уче', 'авю', ' вж', 'пол', ' кг', 'ухи', ' ус', 'отс', 'вев', 'бав', 'и к', ' ри', 'кув', 'ж э', 'дич', 'ием']

# %%
art_ppmi = {}
for w, contexts in smoothppmi.items():
    art_ppmi[w] = contexts['art']
art_top_threehundred = sorted(art_ppmi, key = art_ppmi.get, reverse=True)[:300]
print(art_top_threehundred)
# Out:
# ['яша', 'ьеф', 'тюд', 'ьпт', 'чюр', 'зей', 'авю', 'льп', 'юра', 'хае', 'дсн', 'юр ', 'эст', 'мбр', 'кая', 'гиа', 'луэ', 'дте', 'даи', 'зым', 'вящ', 'сри', 'йза', 'худ', 'уин', 'окг', 'вв ', 'звк', 'фаэ', 'юст', 'урд', 'нуч', 'еи ', 'бэн', 'рфо', 'ухт', 'тюр', 'аэл', 'эрм', 'льв', 'идц', 'эск', 'кмк', 'баи', 'зм ', 'вев', 'урб', 'нуэ', ' ху', 'ярк', 'улы', 'ивь', 'вюр', 'ике', 'оцр', 'умч', 'дип', 'яму', 'юлл', 'хоф', 'адь', 'изо', 'имс', 'ншн', 'одб', 'реф', 'дяс', 'амд', 'удд', 'вгу', 'лфе', 'тоа', 'куи', 'ьян', 'ртр', 'мув', 'имт', 'зыс', 'сх ', 'иус', ' зю', 'шух', 'зоб', 'ауч', 'пущ', 'кув', 'лах', 'цог', ' пх', 'ьбе', 'ыня', 'ырв', 'мэр', 'окт', 'щаг', 'гмо', 'хуж', 'пху', 'лув', 'еща', ' рю', 'йге', 'зск', 'нро', 'ф х', 'лзе', 'окн', 'коя', 'афр', ' сш', 'ядз', 'ь… ', 'еоф', 'узн', 'жни', 'эйф', 'нев', 'жов', 'едр', 'щуч', 'сбл', 'шле', 'стх', 'дад', 'клы', 'ныш', 'э т', 'уаш', 'уж ', 'евн', 'тк ', 'змя', 'хаю', 'мпу', 'еуб', 'зящ', 'ись', 'сец', ' ял', 'кэн', 'к ц', ' тч', 'т ю', 'вце', 'ацв', ' оя', 'овл', 'атл', 'гап', 'гоц', 'ейг', 'пту', 'онм', 'атю', 'вбл', 'сшт', 'бюс', ' ям', 'вкл', 'увш', 'вк ', 'аяц', 'ойс', 'ьту', 'бля', 'сой', 'рье', 'ц е', 'ант', 'тн ', ' цв', 'ане', 'цин', 'еул', 'енш', 'гип', 'амч', 'йет', ' лл', 'юрм', 'чил', 'шоч', 'х и', 'емч', 'цки', 'и э', 'ынь', 'мпе', 'лут', 'тву', 'вуз', ' вх', 'ару', 'мие', 'юре', 'икл', 'ялт', 'шаг', ' ри', 'ячи', 'ьцо', ' об', 'имв', 'нщи', 'ног', 'жчи', 'ием', 'дгл', 'щни', 'пье', 'мур', 'лте', 'дб ', ' ам', 'зня', 'вяг', 'р д', 'ису', 'епи', 'ы ж', 'нба', 'тща', ' вж', 'или', 'бая', 'уче', 'кну', 'ощр', 'к я', 'вко', ' ° ', 'рив', 'лое', 'ячо', 'к ф', 'рео', 'ени', 'шаф', 'оит', 'вру', 'рес', 'гее', ' эс', 'ху ', ' зм', 'ухв', 'бви', 'их ', 'овс', 'в ф', 'одь', 'гюг', 'ачч', 'ваг', 'кво', 'мох', ' хм', 'щиц', 'кен', 'упо', ' дп', 'пия', 'увр', 'ядя', 'сун', 'оцв', 'нбе', 'ычу', ' ол', 'окр', 'тин', 'сси', 'юрн', 'уир', 'цез', 'имд', 'люм', 'цап', 'оил', 'шил', 'гоб', 'тая', 'ыд ', 'еез', 'ехт', 'азг', 'зне', 'лье', 'ндт', 'оче', 'теф', 'туш', 'ччо', 'шие', 'эрр', 'ьям', 'кут', ' ак', 'соч', 'тг ']

# %%
books_ppmi = {}
for w, contexts in smoothppmi.items():
    books_ppmi[w] = contexts['books']
books_top_threehundred = sorted(books_ppmi, key = books_ppmi.get, reverse=True)[:300]
print(books_top_threehundred)
# Out:
# ['урд', 'умч', 'вящ', 'улы', 'кая', 'упо', 'ухт', 'или', 'ауч', ' об', 'отз', 'з г', 'дте', 'ярк', 'доф', 'одб', 'рье', 'в ф', 'ане', 'т ю', 'ы ж', 'мур', 'нев', ' ха', 'бля', 'ног', 'шат', 'жба', 'и э', 'льв', ' ам', 'х и', 'ант', 'гюг', 'уж ', 'окт', 'атл', 'лол', 'кен', 'уин', 'икл', 'тби', 'к ф', ' ол', 'идц', 'у о', 'ост', 'зм ', ' сш', 'цки', 'р д', ' уж', 'ару', 'евн', 'вгу', 'яса', 'ойс', 'чие', 'ени', 'реф', 'пия', 'ены', 'зг ', 'ндл', 'е г', 'имс', 'окг', 'адь', 'лое', 'арп', 'эйф', 'баи', 'удр', 'мув', 'овс', 'юр ', 'о м', ' зм', 'гиа', 'эст', 'шле', 'гед', ' рю', 'вкл', 'тат', 'зыс', 'бви', 'кка', 'узн', 'орж', 'пет', 'л т', 'оче', 'ыня', ' ям', 'ные', 'кат', 'н в', 'еща', 'оит', ' пи', ' вх', 'одь', 'вме', 'тез', 'эрр', 'бэн', ' мэ', 'нгу', 'лиш', 'уче', ' кн', 'овл', 'ячи', 'убо', 'тюд', 'зне', 'зиа', 'слу', 'рес', 'рем', 'ьян', 'иву', 'к ц', 'цин', 'зик', 'ающ', 'лих', 'бза', 'ыбе', 'ьцо', 'хну', 'жда', 'смо', 'яст', 'нщи', 'яму', 'езн', 'гко', 'роу', 'сси', 'о ч', 'вев', 'дип', 'юча', 'гом', 'бир', 'урб', 'реб', 'мум', 'удд', 'едр', 'рив', 'тву', 'зым', 'мор', 'кес', 'я я', 'амю', 'пье', 'виш', 'кну', 'яро', 'чеб', 'лут', 'ека', 'рои', 'чон', 'азг', 'дой', 'ивь', 'иты', 'м з', ' зю', 'вк ', 'ахл', 'чте', 'адц', 'дя ', 'биб', 'соч', 'г у', 'окл', 'одв', 'ыво', 'дсн', 'пел', 'уки', 'нее', 'гки', 'фэн', ' ус', 'кво', 'исы', 'мму', 'з п', 'спи', 'щин', 'мох', 'жаз', 'туш', 'сей', 'едл', ' сж', 'бли', 'мст', 'еже', 'моэ', 'евд', 'цан', ' ак', 'окр', 'мед', 'жчи', 'р о', 'изр', 'агл', ' хм', 'поп', ' пр', 'кэн', 'ь… ', 'и к', 'рба', 'кэт', 'ьбе', 'еуб', 'пиц', 'обх', 'ьту', 'ати', 'сшт', 'ств', 'есб', 'шел', ' шк', 'а э', 'гап', 'мэр', ' дл', 'бер', 'изд', 'тзы', 'изо', 'окн', 'нем', ' ци', 'тво', 'сфе', ' гэ', 'ача', 'щиц', 'чны', 'сай', 'вв ', 'пол', 'гул', 'к я', 'иас', 'учн', 'дич', 'мощ', 'у ч', 'евс', 'клы', 'онг', 'нау', 'пущ', 'дут', 'уси', 'кни', 'тюр', 'дар', 'ф х', 'емя', 'ядя', 'рдж', 'вко', 'юра', 'схв', 'лди', 'асс', ' гю', 'зск', 'бум', 'ием', 'мие', 'ано', 'кле', 'рож', 'щни', 'кше', 'е е', 'рг ', 'лга', 'ныш', 'кут', 'нро', 'яжн', 'стф']

# %%
films_ppmi = {}
for w, contexts in smoothppmi.items():
    films_ppmi[w] = contexts['films']
films_top_threehundred = sorted(films_ppmi, key = films_ppmi.get, reverse=True)[:300]
print(films_top_threehundred)
# Out:
# ['умч', 'иву', 'ндл', ' сш', ' бю', 'уин', 'ярк', 'вк ', 'мур', 'дте', ' лл', 'в ф', 'урд', 'кэм', 'зиа', ' ам', 'к ф', 'ант', 'ьцо', 'упо', 'вящ', 'рье', 'реф', 'вкл', 'ауч', ' об', 'овл', 'мув', 'тби', 'лол', 'пз ', 'ног', 'одб', 'доф', 'ане', ' ак', 'ьм ', 'з г', 'ухт', 'и э', 'улы', 'идц', 'р д', 'или', 'льв', 'хоу', 'т ю', 'отз', 'спи', 'зв ', 'м з', 'нев', 'бля', 'чие', ' ха', 'окт', 'эст', 'имс', 'ост', 'шат', 'х и', 'у о', 'юча', 'смо', 'убр', 'вгу', 'эме', 'гиа', ' ол', 'зм ', 'яму', 'зг ', 'дб ', 'овс', 'кмк', 'нро', 'куа', 'юсе', 'ойс', 'бир', 'юр ', ' уж', ' мэ', 'ные', 'ени', 'мед', 'мэр', 'лбе', 'икл', 'онг', 'мум', 'ены', ' вх', 'яро', 'о м', 'имд', 'жба', 'тву', 'е г', 'нац', 'жаз', 'кат', 'пия', 'кая', 'вце', 'кка', 'гма', 'оит', 'ивь', 'жда', 'сси', '“ ”', 'вме', 'еуб', 'л т', 'еща', 'шле', 'евн', 'ару', 'удр', 'лое', 'ухи', 'арп', 'тез', 'рив', 'ы ж', 'лиш', ' лф', 'слу', 'хну', 'бви', 'н в', 'оче', 'нем', 'едл', 'дсн', 'тюд', 'куи', 'тат', 'сшт', 'ячо', 'к я', 'баи', 'ьту', 'одв', 'цки', 'нои', 'рем', 'окг', 'рес', 'ячи', 'гед', 'иль', 'ф х', 'ш т', 'одь', 'коя', 'ште', 'бое', 'саг', 'ием', 'иар', 'хич', 'убо', 'езн', 'яша', 'ея ', ' ус', 'лих', 'зне', 'тпа', 'ьси', 'мму', 'уче', 'кен', 'хпз', 'зик', 'яса', ' пи', 'щее', 'цан', 'азг', 'яст', 'я я', 'р о', 'к ц', 'едр', 'пиц', 'поп', 'нее', 'шаз', ' пр', 'и к', 'окр', 'йле', 'реб', 'риц', 'ати', 'обх', 'уве', 'гаг', 'схв', 'зск', 'рре', 'вяг', 'апс', 'ыня', 'ств', ' сп', 'ьян', 'уж ', 'ыво', 'ващ', 'дя ', ' кн', 'рфо', 'кле', 'кэн', 'кте', 'эйф', 'орж', 'пай', 'кну', 'зыс', 'нщи', 'еже', 'енш', 'дой', 'пол', 'фэн', 'шан', 'мст', 'пущ', 'тво', 'ающ', 'пет', 'нуэ', 'атл', 'гко', 'бль', 'атр', ' мб', 'ача', 'ауд', 'нбе', 'кво', 'циф', 'рли', 'вев', 'мох', 'тну', 'окз', 'анс', 'есб', ' хс', ' хм', 'з п', ' кч', 'мощ', 'шоу', 'адь', 'мэй', 'йан', 'кик', 'опл', 'бли', 'сей', 'о ч', 'изо', 'эмм', 'бер', 'ф и', 'льд', 'екв', ' ям', 'дар', 'роу', ' сж', 'ека', 'бет', 'рои', 'кри', 'мор', 'гюг', 'адц', 'агл', 'кше', 'ы э', 'теа', 'узн', 'худ', 'оуш', 'нау', 'ано', ' юз', 'дюс', 'тт ', 'арч', 'чны', 'дут']

# %%
food_ppmi = {}
for w, contexts in smoothppmi.items():
    food_ppmi[w] = contexts['food']
food_top_threehundred = sorted(food_ppmi, key = food_ppmi.get, reverse=True)[:300]
print(food_top_threehundred)
# Out:
# ['ены', 'пиц', 'уж ', 'бля', 'ивь', 'стф', 'жар', ' ол', 'туш', 'ячи', 'урд', 'ауч', 'ы ж', 'вощ', 'з г', 'окт', 'упо', ' об', ' кг', 'ху ', 'ыба', 'зм ', 'ухт', ' уж', 'шаш', 'вко', 'кг ', 'овл', 'сыт', 'гмо', 'шат', 'ног', 'ные', 'зиа', 'адь', 'кая', 'тби', 'едр', 'со ', 'ане', 'нев', 'или', 'хну', 'фе ', 'пет', 'мув', 'вег', ' пи', ' ры', 'о м', 'пел', 'умч', 'ост', 'юр ', 'езн', 'соч', 'сгу', 'мор', 'урб', 'виш', 'бва', 'евн', 'ц е', 'рив', ' рю', 'вме', 'у о', 'к ф', 'ващ', 'буш', 'реб', 'щ ф', 'ьси', 'улы', 'доф', 'цки', 'еже', 'ясо', 'ыкв', 'т ю', 'тоз', 'ант', ' сш', 'мед', 'аке', 'дки', 'и э', 'глю', 'х и', 'оче', 'пче', 'хоф', 'мму', 'ойс', 'ярк', 'тк ', 'чие', 'чиц', 'к я', 'е е', 'етч', 'рож', 'яст', 'тпа', 'тиб', 'вев', 'кат', 'ени', 'дсн', 'ару', 'цин', 'звк', 'шле', 'эст', 'овс', 'тфу', 'е г', ' ам', ' сж', 'куш', 'ьян', 'ппе', 'чаш', 'мур', 'щ н', 'юре', 'зг ', 'ням', 'юша', 'удр', 'к ц', 'мум', 'р д', ' мя', 'гр ', 'пча', 'обх', 'зне', 'еща', 'оит', 'реф', 'шоч', 'рье', 'мпу', 'хня', 'арп', 'укр', 'ща ', 'мох', 'рян', 'ьцо', 'бир', 'рш ', ' яг', 'ефи', 'ыня', 'гки', 'укт', 'ь… ', 'оба', 'ьеф', 'чеб', 'ныш', 'орж', 'одб', 'ике', 'узн', 'юча', 'лиш', 'лут', 'н в', 'тат', 'вкл', 'окр', 'ека', 'сое', 'жчи', 'опч', 'тюд', 'сян', 'м з', 'поп', 'нщи', 'фел', 'вящ', 'рем', 'хру', 'щ м', 'бав', 'бжа', 'сыр', 'еуб', 'ш т', 'обм', 'яго', 'кле', 'жжи', 'кож', 'баи', 'отз', 'воя', 'эйф', 'дук', 'пт ', 'одв', 'я я', 'уси', 'дой', ' ха', 'ган', ' ус', 'дич', 'гап', 'пол', 'дип', 'риц', 'окг', 'ивк', 'ычк', 'хла', 'лба', 'юдо', 'вгу', 'гуш', 'лфе', ' пр', ' яи', 'зыс', 'гко', 'чип', 'сах', 'чка', 'газ', 'кош', 'ьдс', 'льв', 'жда', 'лое', 'янь', 'зяй', 'ощ ', 'тву', ' вх', 'еге', 'рес', 'ием', 'втр', 'о ч', 'яму', 'жба', ' хм', 'одь', 'щни', 'слу', 'пше', 'нем', 'асл', 'т я', 'маг', 'ыво', 'л т', 'з п', 'чны', 'зск', 'жий', 'ябл', 'уче', 'гул', 'щин', 'ипс', 'акл', 'нее', 'убо', 'сыщ', 'мид', 'пущ', 'ыпа', 'чуп', 'ати', 'лап', 'нау', 'а э', 'клы', ' оо', 'шеч', 'эти', 'смо', 'рен', 'р о', 'шис', 'ств', ' ям', 'арч', 'ячо', 'ашл', 'тая', 'бви', 'тво', 'илк', 'оку']

# %%
football_ppmi = {}
for w, contexts in smoothppmi.items():
    football_ppmi[w] = contexts['football']
football_top_threehundred = sorted(football_ppmi, key = football_ppmi.get, reverse=True)[:300]
print(football_top_threehundred)
# Out:
# ['улы', 'рье', 'арп', 'упо', 'урд', 'тби', ' об', 'ане', 'в ф', 'ы ж', 'льв', 'или', 'эйф', 'вгу', ' зм', ' ол', 'х и', 'шат', ' ха', 'фут', 'ярк', 'одб', 'к ф', 'и э', 'бля', 'ног', 'цки', 'т ю', 'ауч', 'з г', 'умч', 'л т', ' ам', 'убо', 'кая', 'ост', 'ячи', ' бю', 'о м', 'ант', 'р д', 'нев', 'вящ', 'ены', 'чие', 'ьян', 'ени', 'вкл', 'мум', 'к ц', 'реф', 'у о', 'бви', 'смо', 'окт', 'идц', 'слу', 'ные', 'укр', 'эрр', 'жба', ' сш', 'н в', 'лол', 'атл', ' ям', 'кат', 'вме', ' уж', 'ойе', 'иев', 'ухт', 'зм ', 'ару', 'гба', 'пет', 'доф', 'шов', 'яму', 'оит', 'сси', 'авм', 'удр', 'е г', 'апл', 'хну', 'жда', 'бир', 'мур', 'овс', 'едр', 'овл', ' вх', 'зиа', 'лиш', 'лое', 'азг', 'еща', 'яст', 'пел', 'юча', 'оче', 'эст', 'ике', 'езн', 'тат', 'дой', 'рив', 'сай', ' ус', 'рба', 'цан', 'рес', 'ающ', 'адь', 'лих', 'нба', 'юра', 'яса', 'дя ', 'реб', 'уеф', 'иву', ' дз', 'орж', 'кен', 'зг ', 'м з', 'я я', 'рен', 'рем', 'уси', ' пр', 'ващ', 'и к', 'едл', 'одв', 'дут', 'пз ', 'шах', 'баи', 'ныр', 'ш т', 'ьта', 'тпа', 'отз', 'яро', ' пи', 'пол', 'уве', 'имс', 'дар', 'лям', 'ати', ' иг', 'онг', 'сфе', 'аке', 'ойс', 'зик', 'обх', 'евн', 'л б', 'зен', 'узн', 'юка', 'мед', 'иас', 'вко', 'ыво', 'хте', 'ано', 'урб', ' сп', 'иол', 'туш', 'кка', 'еже', 'йес', 'эме', 'шле', 'аля', 'зне', ' ак', 'е е', 'зе ', 'ь… ', 'еуб', 'рре', 'уче', 'р о', 'поп', ' мя', 'спи', 'шан', 'луз', 'ыго', 'тву', 'щик', 'клу', 'бав', 'нем', 'агл', 'гом', 'бли', 'идж', 'дте', 'рв ', 'к я', 'о ч', 'жар', 'изр', 'ача', 'анц', 'ц е', 'пиц', 'з п', 'мощ', 'гед', 'екв', 'гко', 'нхе', 'рян', 'уин', 'рои', ' лл', 'быг', 'ент', 'икл', 'щни', 'ефа', 'але', 'нее', 'кну', 'анс', 'лбе', 'гуш', 'лди', 'пущ', 'стф', 'бер', 'окл', 'гул', 'ю п', 'ыт ', 'лн ', 'гр ', 'ав ', 'ств', 'дад', 'а в', 'кле', 'сей', 'ы э', 'гру', 'иар', ' ля', 'изо', 'ья ', 'си ', 'итн', 'дин', 'ивь', 'ь о', 'мох', 'льд', 'а э', 'ху ', 'тво', 'ште', ' ух', 'ч в', 'л в', 'ваг', 'а п', 'ащи', 'дич', 'поз', 'гов', 'одь', 'кик', 'бка', 'згр', 'уж ', 'рна', 'лый', 'ыбе', 'ста', ' лч', 'окр', 'юр ', 'чны', 'ех ', 'янд', 'исы', 'емя', 'ича', 'год', 'оба', 'хоф']

# %%
games_ppmi = {}
for w, contexts in smoothppmi.items():
    games_ppmi[w] = contexts['games']
games_top_threehundred = sorted(games_ppmi, key = games_ppmi.get, reverse=True)[:300]
print(games_top_threehundred)
# Out:
# ['упо', ' об', 'рье', 'лол', 'урд', 'улы', ' ха', 'дут', 'или', 'ане', ' бю', 'х и', 'умч', 'кая', 'одб', 'ног', 'и э', 'льв', 'ауч', 'з г', 'к ф', 'шат', 'т ю', ' ол', 'тби', 'бля', 'доф', 'арп', 'вящ', 'в ф', 'ост', 'ярк', 'ы ж', 'нев', 'чие', 'р д', 'отз', 'ены', 'вкл', 'атл', 'ные', 'л т', 'ячи', 'у о', 'зик', 'ант', 'о м', ' ам', ' сш', 'мум', 'лут', 'убо', 'кше', 'ени', 'реф', 'е г', 'юча', ' уж', 'ухт', 'кат', 'цки', 'овл', 'ойс', 'зг ', 'пия', 'вме', 'имс', 'смо', 'еща', 'фут', 'хну', 'кик', 'эйф', 'вгу', 'н в', 'оит', 'зм ', 'иву', 'окт', 'лиш', 'лое', 'бир', 'жда', 'оче', 'рив', 'овс', 'яст', 'пиц', 'мур', 'езн', 'адь', 'ару', 'мув', 'сай', 'тат', 'кен', 'удр', ' ус', ' вх', 'азг', 'дя ', 'едр', 'цан', 'евн', 'рес', 'жба', 'к ц', ' иг', 'слу', 'ващ', 'одв', 'сси', 'реб', 'икл', 'туш', ' мэ', ' зм', ' пи', 'рем', 'йле', 'узн', 'уин', 'укр', 'юр ', 'лям', ' дл', ' пр', 'бое', 'ыня', 'глю', 'м з', 'идц', 'зиа', 'ндл', 'сфе', 'яму', 'пет', 'тпа', ' юз', ' ак', 'бви', 'сшт', 'вег', 'яса', 'кэн', 'эст', 'мед', 'аля', 'ати', 'мощ', 'и к', 'уче', 'а э', 'иар', 'ьян', 'мор', 'пол', 'ьцо', 'р о', 'уж ', 'бет', 'я я', 'обх', 'ы э', 'зв ', 'г у', 'тез', 'бли', 'одь', ' ям', 'циф', 'ху ', 'апл', 'едл', 'орж', 'изо', 'спи', 'амд', ' мб', 'нее', 'ано', 'ркр', 'гко', 'ыво', 'з п', 'ача', 'шов', 'кле', 'рен', 'еже', 'нем', 'ающ', 'щни', 'поп', 'шле', 'кка', 'вко', 'схв', 'о ч', 'к я', 'ейв', 'гр ', 'дар', 'уси', ' сп', 'урб', 'окр', 'вк ', 'гап', 'уве', 'а в', 'руш', 'екв', 'сей', 'ека', 'хла', 'аке', 'агл', 'мпу', 'окл', 'дип', 'еуб', 'соч', 'виш', 'ств', 'чны', 'иг ', 'зне', 'гуш', 'идж', 'кну', ' ож', 'дте', 'ячо', 'рба', 'тво', 'гом', 'яро', 'ь о', 'а п', 'тву', 'экш', ' гт', 'нба', 'оба', 'айф', 'отл', ' ля', 'ент', 'бав', 'к в', 'лн ', 'гов', 'онг', 'аят', 'хоу', 'физ', ' ры', 'емя', 'л б', 'ейд', 'але', 'е е', 'иас', 'дин', 'отс', 'лне', 'ста', 'гру', ' хм', 'ыго', 'рои', 'лый', 'тну', 'гул', 'кон', 'учн', 'гед', 'тсу', 'пущ', 'гиа', 'инг', 'акл', 'тль', 'бог', 'бка', 'гки', 'лих', 'исы', 'ф х', 'ый ', 'гив', 'кув', 'бль', ' сж', 'офи', 'даи', 'р у', 'уте', 'ижо']

# %%
music_ppmi = {}
for w, contexts in smoothppmi.items():
    music_ppmi[w] = contexts['music']
music_top_threehundred = sorted(music_ppmi, key = music_ppmi.get, reverse=True)[:300]
print(music_top_threehundred)
# Out:
# ['шат', 'жаз', 'упо', ' об', ' ха', 'рье', 'ног', 'ане', 'слу', 'ант', 'ост', 'или', 'вящ', ' ол', 'к ф', 'ени', ' ам', 'о м', 'бля', 'одб', 'нев', 'ярк', 'и э', 'пет', 'вкл', 'цки', 'чие', 'л т', 'убо', 'лол', 'р д', 'лое', 'е г', 'атл', 'оче', 'ауч', 'х и', 'кат', 'вме', 'лиш', 'сси', 'у о', ' мэ', ' иг', 'зг ', 'зм ', 'юча', 'жда', 'тат', 'смо', 'овс', 'овл', 'яса', 'рем', 'н в', 'виш', ' ус', 'ару', 'сай', 'рес', 'эст', 'м з', 'умч', 'рив', 'мур', 'гру', 'з г', 'окт', ' пр', 'бир', 'поп', ' пи', ' вх', ' ак', 'ные', ' уж', 'ати', 'зик', 'мум', 'оит', 'реб', 'узн', 'мощ', 'еща', 'одв', 'спи', 'имс', 'нем', 'езн', 'дич', 'окл', 'дар', 'пол', 'евн', 'ача', 'а э', 'кая', 'в ф', 'ано', 'ены', 'т ю', 'и к', 'дя ', 'урд', 'цан', 'кен', 'идж', 'ьян', 'арп', 'рен', 'з п', 'ающ', 'удр', 'сфе', ' сп', 'реф', 'р о', 'ващ', 'соч', 'ств', 'улы', 'икл', 'чны', 'нее', 'отз', 'тез', 'тво', 'сей', 'бли', 'ейв', 'туш', 'отл', 'едл', 'гиа', 'емя', 'ь о', 'кну', 'гко', 'дип', 'азг', 'исы', 'ент', 'ойс', 'онг', 'мед', ' юз', 'ячи', 'а в', 'а п', 'оба', 'укр', 'я я', 'дой', 'вгу', 'иар', 'пел', 'лне', 'еже', 'ста', 'о ч', 'дин', 'ыво', 'поз', 'аля', 'хну', 'фут', 'гов', 'тби', 'ый ', 'льв', 'кон', 'кле', 'зыс', ' сш', 'ека', ' ож', 'гки', 'к в', 'ебя', 'бав', 'агл', 'ивь', 'ейб', 'рои', 'асс', 'пия', 'ы э', 'юз ', 'изо', 'але', 'айф', 'кка', 'лый', 'одь', ' дл', 'апл', 'кес', 'инг', 'туб', 'тву', 'мор', 'щик', 'нщи', 'уси', 'п р', 'л б', 'иев', 'акж', 'бет', 'блэ', ' ля', 'циф', 'зне', 'п о', 'йле', 'вой', 'анс', 'мэй', 'иг ', 'еге', 'зат', 'гом', ' хм', 'мст', 'сшт', 'ей ', 'нау', 'уче', 'офи', 'оти', 'йт ', 'бэн', 'едр', 'лед', 'год', 'отс', 'обс', 'фон', ' ст', 'уве', 'иль', 'чил', ' ух', 'ндт', 'дэт', ' бо', 'льб', 'ячо', 'стк', ' ям', 'дут', 'сэм', 'лдс', 'рре', 'анц', 'льн', 'доф', 'сау', 'лут', 'обх', 'ича', 'ция', 'мбр', 'шле', 'л в', 'у н', 'змо', 'рож', 'спр', 'екв', ' хэ', 'бое', 'е н', 'к ц', 'лав', 'т д', 'окр', 'эйф', 'ще ', 'вег', 'бог', ' вж', 'эни', 'чка', 'ний', 'роу', 'я а', 'дос', 'стф', 'муз', 'ойт', 'игр', 'вев', 'дте', 'я э', 'шан', 'гив', ' ди', 'нра', 'тпа']

# %%
nature_ppmi = {}
for w, contexts in smoothppmi.items():
    nature_ppmi[w] = contexts['nature']
nature_top_threehundred = sorted(nature_ppmi, key = nature_ppmi.get, reverse=True)[:300]
print(nature_top_threehundred)
# Out:
# ['тиц', 'рир', 'ены', 'ени', ' пр', 'ост', ' цв', ' об', ' пт', 'кле', 'лый', 'озд', 'чка', 'тат', 'бли', 'а в', 'окн', 'вбл', 'ый ', 'рев', 'лед', 'роз', 'оба', 'ук ', 'кат', 'яго', 'шат', 'бь ', 'ний', 'дет', 'ека', 'ляд', 'ано', ' яг', 'а п', 'ста', 'етк', 'оти', 'сот', 'о м', 'ств', 'тво', 'во ', 'окр', 'пол', ' гн', 'ь о', 'ышь', ' ле', 'бир', 'оче', 'жий', 'але', 'год', 'вце', 'туб', 'ныш', 'дин', 'поп', 'ати', 'ерх', 'ача', 'ес ', 'кош', 'убо', 'шка', ' зм', 'вес', 'рен', 'к в', 'поз', 'одв', 'лиш', 'щни', ' сп', 'ыпа', 'вот', 'пох', 'хво', 'овс', 'вой', ' ют', 'дна', 'изо', 'аво', ' сф', 'зме', 'род', ' бо', 'кри', 'кно', 'дуб', 'азг', ' ус', 'емя', 'ног', ' ст', 'рем', 'мед', 'льн', 'зем', 'сек', 'лес', 'й л', 'фот', 'зь ', 'идт', 'вче', 'йст', 'фон', 'смо', 'бав', 'зат', 'ца ', 'обь', 'гля', 'нев', 'сег', 'о ч', 'об ', 'дти', 'ти ', 'е н', 'рив', 'кво', 'виж', 'чны', 'отк', 'рки', ' вж', 'син', 'наж', 'дня', 'й ф', 'ень', 'д в', 'кам', 'жив', 'ей ', 'сто', 'дер', 'мох', 'изд', 'обл', 'неж', ' дя', 'о ц', 'чий', 'вук', 'или', 'сь ', 'раз', 'ху ', 'пом', 'точ', 'мля', 'вир', 'кве', 'чес', 'ина', 'бер', ' пи', 'ярк', 'ябл', 'ант', 'епе', 'я п', 'так', 'ьшо', 'осл', 'блю', ' ря', 'нно', 'уче', 'одп', 'гул', 'слу', 'жда', 'ащи', 'шис', 'ару', 'лка', 'ух ', 'х л', 'чей', 'й в', 'ссы', ' си', 'иро', 'поч', 'олз', 'н в', 'тог', 'опа', 'хож', 'язь', 'хну', 'аст', 'исы', 'асс', 'л в', 'ихо', 'нем', 'гру', 'нед', 'лне', 'к я', ' иг', 'лб ', ' пе', 'ивн', 'еже', 'ив ', ' ел', 'ращ', ' ры', 'нни', 'льб', 'ычн', 'ще ', 'ету', ' че', 'сви', ' вв', 'дой', 'агл', 'ие ', ' то', ' вс', 'пря', 'две', ' де', 'я я', 'зен', 'сен', 'уве', 'кар', 'кон', 'бел', 'наб', 'сть', 'очь', 'аск', 'ров', 'яде', 'йза', 'сиб', 'рес', 'гад', 'рез', 'изк', 'ь г', 'цве', 'ь к', 'евн', 'лаз', 'лот', ' зе', 'ери', ' ще', 'мор', 'р о', 'хоз', 'луб', 'т з', 'пыш', 'дач', 'нов', ' мя', 'гиг', 'вме', 'оде', 'пти', 'кну', 'а э', 'юту', 'сит', 'рол', 'вок', ' сю', 'сти', ' дл', 'ыма', 'убь', 'руш', 'тка', 'ужа', ' уд', 'оит', 'иль', 'рои', 'воз', 'его', 'акт', 'дол', 'бра', ' сл', 'ойт', ' ха', 'м з']

# %%
travel_ppmi = {}
for w, contexts in smoothppmi.items():
    travel_ppmi[w] = contexts['travel']
travel_top_threehundred = sorted(travel_ppmi, key = travel_ppmi.get, reverse=True)[:300]
print(travel_top_threehundred)
# Out:
# [' об', 'ост', 'ени', 'шат', 'ног', 'о м', 'оче', 'кат', 'тат', 'смо', ' пр', 'ант', 'рес', 'слу', 'бир', 'ане', 'пол', 'рем', 'рив', 'нев', 'пет', 'или', 'ати', 'е г', 'жда', 'атл', ' пи', 'реб', ' ус', 'р д', 'мор', 'ств', 'н в', 'сси', 'а в', 'ь о', ' сп', 'а п', 'поп', 'тво', 'оит', 'еща', 'а э', 'ано', 'чны', 'рен', 'ый ', 'ста', ' ам', 'але', 'ент', 'юча', ' уж', 'дин', 'бли', 'лиш', 'вкл', 'о ч', 'нем', 'р о', 'лый', 'езн', 'гов', 'ача', 'ека', 'и к', 'емя', 'гул', 'год', 'кон', 'ьян', 'окр', 'асс', ' бо', 'к в', ' ст', 'овс', 'гру', 'жар', ' ак', 'зат', 'нее', 'зм ', 'адь', 'уте', 'ция', 'вой', ' ха', 'льн', 'отл', 'отз', 'рож', ' иг', 'евн', 'вме', 'мум', 'сей', 'дар', 'чка', 'ены', 'нед', 'ще ', 'бер', 'анс', 'едл', 'узн', 'ас ', 'ень', 'е н', 'уве', 'чие', 'ей ', 'упо', 'нно', 'з п', 'ний', 'род', 'д в', 'лед', 'изо', 'опа', 'е е', 'обс', 'во ', 'иль', ' це', 'дос', 'инг', 'сфе', ' вх', 'цки', 'убо', 'обх', 'анц', 'лне', 'спр', 'поз', 'т д', 'я п', 'спи', 'рье', 'сот', 'змо', 'лав', 'гко', 'ающ', 'оба', 'езж', ' ол', 'у о', 'а р', 'укр', ' сш', 'соч', 'бра', 'я а', ' че', 'рои', 'ьги', 'л т', 'еги', 'офи', 'вес', 'ьшо', ' дл', 'я э', 'и э', 'чес', 'оти', 'бав', 'бще', 'азг', 'акт', 'к ф', 'ару', 'сь ', 'сто', 'дет', 'ери', 'раз', 'зем', 'нра', 'улы', 'хну', 'пое', ' ры', 'бля', 'отс', 'ебя', 'жно', 'р с', ' бю', 'бог', 'фе ', ' ди', 'лое', 'ляд', 'м з', 'оку', 'фут', 'фон', 'ца ', ' ле', 'дан', 'жий', 'шин', 'ал ', 'вгу', 'кар', ' то', 'уче', 'бль', 'кош', 'льс', 'рг ', 'каз', 'дли', 'исы', 'обл', 'аво', 'ича', 'мед', 'иты', 'деш', ' др', 'бхо', 'ече', 'ина', 'сть', 'дя ', ' ча', 'поч', 'л в', 'уг ', 'нни', 'учн', ' уд', 'уж ', 'тин', 'ер ', 'етк', 'воз', ' пе', 'ращ', 'е р', 'т з', 'ь г', 'маг', 'е ч', 'бяз', 'ойс', 'икл', 'та ', 'еля', ' ух', 'лик', 'сла', 'одв', 'ожд', ' фр', 'муз', 'лем', 'нин', 'нав', 'се ', 'яса', 'есп', 'йст', 'й в', 'ое ', 'зов', 'ычн', 'апл', 'ойт', 'сов', 'ея ', 'рны', 'ров', ' эк', 'ьту', 'т и', 'газ', 'тзы', 'окт', 'кри', 'очь', 'игр', 'анн', 'знь', 'еоб', 'кну', 'жит', 'иба', 'с о', 'аби', 'ерь', 'дст', 'ткр', 'ама', 'мля']

# %%
topthreehundred = {}

# %%
for i in categs:
    topthreehundred[i] = eval(i + '_top_threehundred')

# %%
with open('300 trigrams ppmi.pkl', 'wb') as tp:
    pkl.dump(topthreehundred, tp)
tp.close()
