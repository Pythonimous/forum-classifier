# %%
import pickle as pkl
import math
from tqdm import tqdm

# %%
with open('Matrix Absolute Nonsmooth.pkl', 'rb') as m1:
    wout_smoothing = pkl.load(m1)
m1.close()

# %%
with open('Matrix Absolute Add2 Lessthan0.01.pkl', 'rb') as m2:
    with_smoothing = pkl.load(m2)
m2.close()

# %%
def p_wc(word, context_word, counts, total_counts):
    return counts[word][context_word] / total_counts

# %%
def p_w(word, counts, total_counts):
    return sum(counts[word].values()) / total_counts

# %%
def p_c(context_word, counts, total_counts):
    return sum(freqs.get(context_word, 0) for freqs in counts.values()) / total_counts

# %%
def pmi(word, context_word, counts, total_counts):
    ans = (p_wc(word, context_word, counts, total_counts) /
          (p_w(word, counts, total_counts) * p_c(context_word, counts, total_counts)))
    if ans:
        return math.log2(ans)
    else:
        return 0

# %%
def ppmi(word, context_word, counts, total_counts):
    ans = pmi(word, context_word, counts, total_counts)
    return ans if ans > 0 else 0

# %%
def get_total_counts(counts):
    """counts is a dict of dicts"""
    return sum([sum(vals.values()) for vals in counts.values()])

# %%
def build_matrix(counts):
    total_counts = get_total_counts(counts)
    total_words = len(counts)
    print('working out PPMI')
    for w, contexts in tqdm(counts.items()):
        for c in contexts:
            counts[w][c] = ppmi(w, c, counts, total_counts)
    print('done with PPMI')
    return counts

# %%
smoothppmi = build_matrix(with_smoothing)
# Out:
#   1%|          | 19/2532 [00:00<00:13, 180.86it/s]
# working out PPMI
# 100%|██████████| 2532/2532 [00:13<00:00, 188.98it/s]
# done with PPMI

# %%
with open('PPMIs Add-2 0.01.pkl', 'wb') as p1:
    pkl.dump(smoothppmi, p1)
p1.close()

# %%
def rank_words(counts):
    mean_ppmi = {}
    top_ppmi = {}
    for w, contexts in counts.items():
        vals = list(contexts.values())
        mean_ppmi[w] = sum(vals) / len(vals)
        top_ppmi[w] = max(vals)
    order_mean = sorted(mean_ppmi, key=mean_ppmi.get, reverse=True)
    order_top = sorted(top_ppmi, key=top_ppmi.get, reverse=True)
  #  print(order_mean, file=open('words by mean ppmi no lem.txt', 'w', encoding='utf-8'))
  #  print(order_top, file=open('words by top ppmi no lem.txt', 'w', encoding='utf-8'))
    return order_top

# %%
categs = ['anime', 'art', 'books', 'films', 'food', 'football', 'games', 'music', 'nature', 'travel']

# %%
anime_ppmi = {}
for w, contexts in smoothppmi.items():
    anime_ppmi[w] = contexts['anime']
anime_top_fifty = sorted(anime_ppmi, key = anime_ppmi.get, reverse=True)[:200]
print(anime_top_fifty)
# Out:
# ['гиас', 'мангак', 'рисовка', 'анимешник', 'полнометражка', 'берсерка', 'полнометражный', 'досматривать', 'отсмотреть', 'тетрадка', 'ева', 'бибоп', 'филлер', 'анимэ', 'сенэн', 'том', 'ученик', 'повседневность', 'кинотеатр', 'студия', 'сейя', 'тайтлы', 'евангелиона', 'блич', 'замок', 'концовка', 'необычно', 'манга', 'доставлять', 'экран', 'мувик', 'тетрадь', 'сиська', 'опенинг', 'хвост', 'иллюстратор', 'лайт', 'дворецкий', 'наруто', 'меч', 'кандинский', 'мультик', 'слетать', 'синкай', 'эстетика', 'фансервис', 'короткий', 'аниме', 'набросок', 'просмотр', 'сериал', 'ужас', 'изящный', 'овашка', 'озвучка', 'эльфийский', 'действие', 'восторг', 'фантастика', 'покемон', 'объектив', 'онгоинг', 'увлечение', 'нарут', 'миядзаки', 'подумать', 'ух', 'обычный', 'искусствовед', 'голубой', 'скрывать', 'темный', 'штамп', 'вампир', 'арка', 'семейство', 'осиливать', 'продолжение', 'охотиться', 'недалеко', 'целиком', 'седзе', 'эндинг', 'шилова', 'остальное', 'рекомендовать', 'вещество', 'радовать', 'ирония', 'посмотреть', 'кисть', 'жанр', 'ленин', 'старинный', 'выставляться', 'анимация', 'связанный', 'способ', 'кошка', 'план', 'тематика', 'порядок', 'половина', 'драма', 'боевой', 'исторический', 'мех', 'индустрия', 'кафешок', 'долгий', 'кп', 'яркий', 'просматривать', 'кино', 'алхимик', 'личность', 'запоминаться', 'бог', 'хентай', 'натура', 'палатка', 'попробовать', 'аудитория', 'японец', 'наличие', 'отсутствие', 'романтика', 'брейгель', 'парень', 'включать', 'затягивать', 'предпочтение', 'откуда', 'отличный', 'записывать', 'небо', 'комедия', 'одинаковый', 'заполнять', 'опасный', 'огонь', 'куст', 'личный', 'мультфильм', 'прямо', 'вести', 'пугать', 'лекция', 'одежда', 'триллер', 'предел', 'спать', 'насекомое', 'поздний', 'другой', 'панк', 'неплохо', 'х', 'тема', 'умирать', 'японский', 'гарнир', 'япония', 'эскиз', 'курортный', 'бронировать', 'день', 'вещь', 'шаг', 'поделиться', 'дюрер', 'совершенно', 'упоминать', 'вселенная', 'диалог', 'сердце', 'дубляж', 'достоинство', 'спецэффект', 'отмечать', 'старый', 'камень', 'фишка', 'вредно', 'девочка', 'прокат', 'наверное', 'елка', 'посоветовать', 'призрак', 'создатель', 'ладно', 'классический', 'вывод', 'составлять', 'крайний', 'развиваться', 'мульт', 'повествование', 'третий']

# %%
art_ppmi = {}
for w, contexts in smoothppmi.items():
    art_ppmi[w] = contexts['art']
art_top_fifty = sorted(art_ppmi, key = art_ppmi.get, reverse=True)[:200]
print(art_top_fifty)
# Out:
# ['шилова', 'кандинский', 'искусствовед', 'репин', 'иллюстратор', 'айвазовский', 'скульптор', 'эскиз', 'брейгель', 'изобразительный', 'кисть', 'дюрер', 'музей', 'выставляться', 'набросок', 'холст', 'возрождение', 'выставка', 'проводница', 'изящный', 'модерн', 'скульптурный', 'ленин', 'эрмитаж', 'лекция', 'старинный', 'эстетика', 'живописец', 'миниатюра', 'гигер', 'фигура', 'краска', 'ученик', 'микеланджело', 'собрание', 'натура', 'рембрандт', 'живопись', 'моне', 'скульптура', 'роспись', 'дали', 'босх', 'магритта', 'изображение', 'никас', 'декоративный', 'рисунок', 'галерея', 'соц', 'глазунов', 'сальвадор', 'полотно', 'импрессионист', 'левитан', 'семейство', 'малевич', 'фрагмент', 'увлечение', 'гиас', 'автопортрет', 'гог', 'шилов', 'размещать', 'гравюра', 'мазок', 'творческий', 'сафронов', 'ренессанс', 'мангак', 'происхождение', 'импрессионизм', 'средневековый', 'картина', 'гиперреализм', 'французский', 'репродукция', 'художник', 'рисовать', 'врубель', 'акварель', 'лиза', 'шагать', 'поздний', 'необычно', 'мастерская', 'тк', 'прикладной', 'анимешник', 'публика', 'одежда', 'пикассо', 'портрет', 'предмет', 'заяц', 'заказчик', 'художница', 'карандаш', 'академический', 'ирония', 'статуя', 'голубой', 'соцреализм', 'хвост', 'шишкин', 'мрамор', 'влажность', 'полнометражка', 'сюрреализм', 'берсерка', 'объектив', 'анатомия', 'рисовальщик', 'искусство', 'иллюстрация', 'рисовка', 'мазня', 'христос', 'скрывать', 'херст', 'аукцион', 'натюрморт', 'ряд', 'исторический', 'зарисовка', 'живописный', 'побережье', 'давид', 'голландский', 'животный', 'архитектор', 'сосна', 'обезьяна', 'ценность', 'керамика', 'ракурс', 'тетрадка', 'палитра', 'целиком', 'контраст', 'ремесло', 'недалеко', 'разбираться', 'крест', 'изображать', 'бибоп', 'филлер', 'период', 'студент', 'вверх', 'дерево', 'телескоп', 'выкладывать', 'храниться', 'современник', 'камень', 'век', 'квадрат', 'досматривать', 'эпоха', 'контекст', 'объект', 'курортный', 'ева', 'фотограф', 'рождаться', 'вуз', 'фотография', 'ван', 'палатка', 'авангард', 'рим', 'сенэн', 'полнометражный', 'гамма', 'насекомое', 'яркий', 'античный', 'рельеф', 'цветовой', 'связанный', 'копировать', 'личность', 'кафешок', 'статья', 'винчи', 'масштаб', 'современный', 'тоска', 'обращаться', 'том', 'нарисовать', 'книжный', 'комар', 'берег', 'видение', 'вы', 'удивительно', 'вена', 'тишина']

# %%
books_ppmi = {}
for w, contexts in smoothppmi.items():
    books_ppmi[w] = contexts['books']
books_top_fifty = sorted(books_ppmi, key = books_ppmi.get, reverse=True)[:200]
print(books_top_fifty)
# Out:
# ['слог', 'паланик', 'книжный', 'роман', 'осиливать', 'изящный', 'действие', 'лекция', 'лондон', 'ученик', 'исторический', 'семейство', 'страница', 'подумать', 'старинный', 'том', 'способ', 'браун', 'премия', 'собрание', 'ирония', 'попробовать', 'концовка', 'ужас', 'фантастика', 'восторг', 'камень', 'короткий', 'огонь', 'французский', 'экран', 'остальное', 'личность', 'вести', 'темный', 'необычно', 'скрывать', 'связанный', 'целиком', 'книга', 'поздний', 'голубой', 'творческий', 'доставлять', 'ленин', 'долгий', 'квартира', 'прямо', 'чтиво', 'умирать', 'рекомендовать', 'метро', 'замок', 'личный', 'слетать', 'счет', 'запоминаться', 'происхождение', 'увлечение', 'публика', 'натура', 'другой', 'бог', 'набросок', 'слушать', 'гиас', 'отсутствие', 'обычный', 'кошка', 'издательство', 'недалеко', 'держать', 'включать', 'искусствовед', 'исключительно', 'день', 'совершенно', 'обращаться', 'кисть', 'вы', 'дорога', 'пугать', 'литературный', 'возрождение', 'объем', 'наверное', 'иллюстратор', 'триллер', 'порядок', 'опасный', 'кандинский', 'третий', 'мангак', 'половина', 'ценность', 'яркий', 'предел', 'полезный', 'аппетит', 'насекомое', 'кофе', 'сердце', 'точка', 'объектив', 'откуда', 'рим', 'брат', 'тематика', 'проза', 'переводчик', 'упоминать', 'самолет', 'одинаковый', 'толстой', 'ух', 'повествование', 'чей', 'период', 'современный', 'сумерки', 'дикий', 'отличный', 'хвост', 'записывать', 'находиться', 'посоветовать', 'поездка', 'удивительно', 'кинотеатр', 'страшно', 'тема', 'план', 'некий', 'масштаб', 'вещь', 'кажется', 'исчезать', 'уходить', 'ряд', 'продолжение', 'меч', 'достоинство', 'минимум', 'кино', 'классический', 'модерн', 'солнечный', 'защита', 'век', 'спать', 'диалог', 'наличие', 'де', 'обложка', 'биография', 'вампир', 'поделиться', 'животный', 'проводить', 'муж', 'туда', 'неплохо', 'предпочтение', 'вывод', 'палатка', 'небо', 'игрушка', 'н', 'заполнять', 'крайний', 'произведение', 'шаг', 'досматривать', 'жанр', 'тк', 'п', 'америка', 'сила', 'фигура', 'литература', 'старый', 'экранизация', 'рождаться', 'состояние', 'кто', 'эстетика', 'отличие', 'оч', 'жена', 'открытый', 'сдавать', 'фрагмент', 'спасибо', 'толстый', 'язык', 'описание', 'брейгель', 'составлять', 'чо', 'сестра']

# %%
films_ppmi = {}
for w, contexts in smoothppmi.items():
    films_ppmi[w] = contexts['films']
films_top_fifty = sorted(films_ppmi, key = films_ppmi.get, reverse=True)[:200]
print(films_top_fifty)
# Out:
# ['фаворитка', 'кинотеатр', 'малек', 'премия', 'исторический', 'кино', 'полнометражный', 'ирония', 'творческий', 'номинировать', 'спецэффект', 'публика', 'экран', 'чтиво', 'академик', 'роман', 'шиндлер', 'индустрия', 'прокат', 'студия', 'отсмотреть', 'включать', 'ужас', 'фантастика', 'поздний', 'лида', 'паланик', 'тематика', 'книжный', 'ученик', 'куарон', 'подумать', 'ленин', 'триллер', 'страница', 'огонь', 'личный', 'голливуд', 'ценность', 'отсутствие', 'французский', 'книга', 'паук', 'хайп', 'связанный', 'голосование', 'вы', 'драма', 'слог', 'актерский', 'способ', 'комедия', 'награждать', 'саппорт', 'предпочтение', 'тема', 'лф', 'кисть', 'темный', 'счет', 'план', 'остальное', 'раздача', 'список', 'награда', 'яркий', 'гиас', 'личность', 'объективно', 'другой', 'морковь', 'квартира', 'вести', 'восторг', 'отмечать', 'сердце', 'точка', 'купер', 'объектив', 'кандинский', 'искусствовед', 'действие', 'наличие', 'небо', 'прямо', 'аудитория', 'критик', 'натура', 'минимум', 'откуда', 'упоминать', 'жанр', 'мангак', 'находиться', 'досматривать', 'целиком', 'браун', 'наверное', 'лекция', 'ряд', 'узкий', 'монтаж', 'эстетика', 'том', 'критерий', 'скрывать', 'фильм', 'половина', 'обычный', 'третий', 'исключительно', 'елка', 'кинематограф', 'йорк', 'режиссерский', 'чужой', 'проводить', 'масштаб', 'рапсодия', 'сага', 'соц', 'совершенно', 'попробовать', 'фигура', 'сумерки', 'выделять', 'криминальный', 'открытый', 'кп', 'пост', 'рождаться', 'хвост', 'порядок', 'одинаковый', 'колман', 'дженкинс', 'глобус', 'уходить', 'чей', 'долгий', 'форум', 'вывод', 'обращаться', 'америка', 'рим', 'изящный', 'отличие', 'проголосовать', 'голосовать', 'д', 'собрание', 'снимать', 'литературный', 'роль', 'клоуз', 'день', 'голос', 'лола', 'записывать', 'эпоха', 'современный', 'номинашка', 'просмотр', 'предел', 'некий', 'кто', 'период', 'голубой', 'актриса', 'толпа', 'режиссер', 'гильдия', 'произведение', 'кэмерон', 'составлять', 'картина', 'опрос', 'одиссея', 'лондон', 'массовый', 'кассовый', 'считать', 'авторский', 'осиливать', 'туда', 'недалеко', 'дикий', 'титаник', 'крайний', 'необычно', 'кинг', 'полнометражка', 'семейство', 'набросок', 'век', 'х', 'контекст', 'завтра', 'гага', 'ансамбль']

# %%
food_ppmi = {}
for w, contexts in smoothppmi.items():
    food_ppmi[w] = contexts['food']
food_top_fifty = sorted(food_ppmi, key = food_ppmi.get, reverse=True)[:200]
print(food_top_fifty)
# Out:
# ['аппетит', 'кофе', 'блюдо', 'гарнир', 'жарить', 'сыр', 'кабачок', 'духовка', 'жареный', 'молочный', 'морковь', 'полезный', 'попробовать', 'яйцо', 'вещество', 'вредно', 'лук', 'животный', 'тк', 'майонез', 'огонь', 'соленый', 'мука', 'семейство', 'добавка', 'фарш', 'салат', 'способ', 'пирог', 'мультиварка', 'мясо', 'питаться', 'кусочек', 'лекция', 'муж', 'вкусный', 'происхождение', 'овощ', 'говядина', 'кошка', 'обычный', 'натура', 'суп', 'белок', 'сметана', 'йогурт', 'яблоко', 'целиком', 'пирожок', 'туда', 'масло', 'уксус', 'употреблять', 'гриб', 'рыбный', 'молоко', 'сухой', 'подумать', 'завтрак', 'желудок', 'слог', 'курица', 'ужас', 'варить', 'старинный', 'поздний', 'рынок', 'напиток', 'день', 'необычно', 'обед', 'исключительно', 'пища', 'магазин', 'недалеко', 'сковородка', 'гречка', 'оч', 'посадить', 'капуста', 'французский', 'сливочный', 'прямо', 'голод', 'суша', 'выпечка', 'квартира', 'связанный', 'вести', 'опасный', 'остальное', 'откуда', 'фигура', 'ужин', 'хвост', 'одинаковый', 'питание', 'нарезать', 'кг', 'камень', 'предел', 'выращивать', 'фаворитка', 'кафешок', 'держать', 'рекомендовать', 'паланик', 'спать', 'организм', 'исчезать', 'чо', 'умирать', 'борщ', 'сверху', 'шоколад', 'дорого', 'вегетарианец', 'картошка', 'запах', 'осиливать', 'кефир', 'соль', 'ирония', 'другой', 'вкусно', 'сорт', 'хлеб', 'пельмень', 'рыба', 'поделиться', 'сочи', 'овощной', 'мак', 'готовить', 'мед', 'творческий', 'гиас', 'насекомое', 'бабушка', 'объем', 'температура', 'перец', 'предпочтение', 'кандинский', 'жена', 'увлечение', 'шашлык', 'печь', 'личный', 'кормить', 'привозить', 'дрянь', 'огурец', 'вареный', 'делать', 'темный', 'мангак', 'пробовать', 'есть', 'свинина', 'съедать', 'берсерка', 'рис', 'оливковый', 'толстый', 'слетать', 'углевод', 'добавлять', 'баранина', 'смесь', 'еда', 'кинотеатр', 'сахар', 'сладкий', 'правильный', 'пр', 'котлета', 'вы', 'готовка', 'храниться', 'долгий', 'книжный', 'кушать', 'малек', 'ученик', 'угодно', 'резать', 'условие', 'совершенно', 'специя', 'тесто', 'простой', 'обжаривать', 'растительный', 'охотиться', 'химия', 'действие', 'палатка', 'натуральный', 'ценность']

# %%
football_ppmi = {}
for w, contexts in smoothppmi.items():
    football_ppmi[w] = contexts['football']
football_top_fifty = sorted(football_ppmi, key = football_ppmi.get, reverse=True)[:200]
print(football_top_fifty)
# Out:
# ['поражение', 'юве', 'полуфинал', 'счет', 'лондон', 'защита', 'подумать', 'вести', 'проводить', 'реал', 'действие', 'роман', 'уходить', 'суарес', 'голубой', 'судья', 'поздравлять', 'отсутствие', 'способ', 'слетать', 'концовка', 'аппетит', 'предел', 'сборная', 'камень', 'опасный', 'ужас', 'мю', 'слог', 'коллектив', 'недалеко', 'оборона', 'включать', 'попробовать', 'целиком', 'полезный', 'остальное', 'удар', 'держать', 'доставлять', 'уход', 'туда', 'ток', 'сибирь', 'посадить', 'публика', 'завтра', 'исторический', 'ирония', 'минимум', 'третий', 'скрывать', 'личный', 'французский', 'связанный', 'другой', 'половина', 'прямо', 'порядок', 'короткий', 'огонь', 'долгий', 'изящный', 'футбол', 'ученик', 'сдавать', 'откуда', 'пас', 'неплохо', 'наверное', 'премия', 'столица', 'находиться', 'план', 'ух', 'день', 'поздний', 'рубин', 'зарабатывать', 'слушать', 'кофе', 'радовать', 'исключительно', 'личность', 'бог', 'сколько', 'обыгрывать', 'отличный', 'хвост', 'лекция', 'масштаб', 'вывод', 'яркий', 'кинотеатр', 'обычный', 'ладно', 'одинаковый', 'кто', 'спать', 'рим', 'том', 'вы', 'открытый', 'страница', 'угодно', 'записывать', 'паланик', 'голландец', 'сила', 'экран', 'де', 'квартира', 'потерять', 'жареный', 'самолет', 'отличие', 'состояние', 'парень', 'контракт', 'футбольный', 'вспомнить', 'совершенно', 'возможность', 'думать', 'дикий', 'гарнир', 'впереди', 'шаг', 'россиянин', 'период', 'англия', 'погулять', 'объективно', 'ряд', 'гиас', 'браун', 'п', 'наличие', 'крайний', 'умирать', 'матч', 'ван', 'чо', 'необычно', 'фаворитка', 'атаковать', 'точка', 'приятно', 'небо', 'вратарь', 'согласный', 'дорога', 'ворота', 'исчезать', 'студия', 'болеть', 'восторг', 'ленин', 'кажется', 'франция', 'месяц', 'книжный', 'фантастика', 'запоминаться', 'чей', 'сердце', 'приличный', 'клуб', 'оч', 'второй', 'конкурент', 'отмечать', 'позволять', 'семейство', 'составлять', 'приносить', 'вверх', 'обращаться', 'вещество', 'собрание', 'осиливать', 'уезжать', 'взять', 'брат', 'сегодняшний', 'успевать', 'поездка', 'условие', 'привозить', 'толпа', 'кандинский', 'заполнять', 'месся', 'сухой', 'фигура', 'тренер', 'отсмотреть', 'кисть', 'лишь', 'страшно']

# %%
games_ppmi = {}
for w, contexts in smoothppmi.items():
    games_ppmi[w] = contexts['games']
games_top_fifty = sorted(games_ppmi, key = games_ppmi.get, reverse=True)[:200]
print(games_top_fifty)
# Out:
# ['действие', 'игрушка', 'способ', 'студия', 'попробовать', 'доставлять', 'ведьмак', 'остальное', 'концовка', 'подумать', 'осиливать', 'счет', 'экран', 'вести', 'огонь', 'третий', 'отсутствие', 'включать', 'поражение', 'ток', 'камень', 'слетать', 'книжный', 'роман', 'защита', 'одинаковый', 'чо', 'короткий', 'открытый', 'обычный', 'связанный', 'реал', 'консоли', 'кинотеатр', 'уходить', 'ужас', 'миссия', 'индустрия', 'самолет', 'недалеко', 'проводить', 'другой', 'исторический', 'предел', 'прямо', 'метро', 'откуда', 'диалог', 'минимум', 'консольный', 'туда', 'масштаб', 'полезный', 'лола', 'целиком', 'план', 'темный', 'восторг', 'держать', 'модерн', 'меч', 'половина', 'аппетит', 'скрывать', 'вселенная', 'порядок', 'удар', 'фантастика', 'умирать', 'наверное', 'ирония', 'кино', 'кофе', 'долгий', 'возможность', 'личный', 'лекция', 'отличие', 'записывать', 'лондон', 'отличный', 'толпа', 'день', 'премия', 'исчезать', 'страница', 'совершенно', 'опасный', 'неплохо', 'рим', 'сколько', 'наличие', 'кисть', 'ух', 'квартира', 'поздний', 'вывод', 'завтра', 'публика', 'голубой', 'д', 'сибирь', 'радовать', 'замок', 'ладно', 'старый', 'точка', 'бог', 'личность', 'изящный', 'угодно', 'небо', 'объективно', 'исключительно', 'пугать', 'шаг', 'кто', 'месяц', 'слог', 'находиться', 'делать', 'паук', 'необычно', 'второй', 'составлять', 'п', 'том', 'крайний', 'фишка', 'яйцо', 'ученик', 'зарабатывать', 'х', 'думать', 'слушать', 'яркий', 'продолжение', 'творческий', 'ряд', 'дикий', 'тематика', 'рынок', 'батл', 'сила', 'лук', 'добавка', 'вспомнить', 'аудитория', 'консоль', 'спать', 'запоминаться', 'тема', 'оборона', 'посадить', 'жарить', 'реальный', 'спецэффект', 'рекомендовать', 'озвучка', 'е', 'кошка', 'разбираться', 'поздравлять', 'жанр', 'блюдо', 'арма', 'хвост', 'сыр', 'какой', 'геймплей', 'обращаться', 'лишь', 'дорога', 'кажется', 'вещество', 'взять', 'судья', 'такси', 'позволять', 'охотиться', 'согласный', 'приятно', 'футбол', 'потерять', 'успевать', 'оружие', 'реалистичный', 'приносить', 'упоминать', 'отличаться', 'де', 'оч', 'убирать', 'суть', 'считать', 'страшно', 'юве', 'предмет', 'удивительно', 'хватить']

# %%
music_ppmi = {}
for w, contexts in smoothppmi.items():
    music_ppmi[w] = contexts['music']
music_top_fifty = sorted(music_ppmi, key = music_ppmi.get, reverse=True)[:200]
print(music_top_fifty)
# Out:
# ['слушать', 'коллектив', 'записывать', 'студия', 'джаз', 'панк', 'метать', 'остальное', 'уходить', 'счет', 'доставлять', 'подумать', 'третий', 'отличный', 'другой', 'пластинка', 'неплохо', 'включать', 'х', 'кино', 'план', 'творческий', 'поздний', 'наверное', 'предпочтение', 'попробовать', 'восторг', 'старый', 'вести', 'обычный', 'жанр', 'радовать', 'ток', 'половина', 'публика', 'совершенно', 'тема', 'умирать', 'страница', 'целиком', 'ладно', 'французский', 'способ', 'отличие', 'личный', 'д', 'кто', 'оч', 'личность', 'премия', 'ряд', 'яркий', 'ссылка', 'рекомендовать', 'прямо', 'запоминаться', 'бог', 'пост', 'вспомнить', 'второй', 'короткий', 'долгий', 'уход', 'поп', 'отсутствие', 'нота', 'согласный', 'откуда', 'е', 'лола', 'парень', 'день', 'думать', 'классический', 'период', 'приятно', 'делать', 'сколько', 'связанный', 'держать', 'вещь', 'темный', 'крайний', 'порядок', 'составлять', 'запись', 'упоминать', 'минимум', 'вывод', 'современный', 'считать', 'разбираться', 'ужас', 'чо', 'лишь', 'какой', 'целое', 'н', 'исключительно', 'кажется', 'чей', 'п', 'диалог', 'проводить', 'точка', 'известный', 'спасибо', 'тяжелый', 'предел', 'полуфинал', 'ух', 'вы', 'некий', 'отличаться', 'сила', 'возможность', 'аудитория', 'слышать', 'диск', 'действие', 'модерн', 'ютуб', 'взять', 'толпа', 'фишка', 'брат', 'простой', 'однако', 'отмечать', 'душа', 'завтра', 'масштаб', 'одинаковый', 'огонь', 'мера', 'осиливать', 'концовка', 'видео', 'шоу', 'скоро', 'находиться', 'вставлять', 'сердце', 'форум', 'выделять', 'выходить', 'попс', 'гениальный', 'настоящий', 'суть', 'качество', 'список', 'голос', 'наличие', 'хоп', 'старинный', 'поздравлять', 'прослушивать', 'индустрия', 'блюз', 'ирония', 'представлять', 'вопрос', 'месяц', 'хард', 'продолжение', 'исчезать', 'вселенная', 'товарищ', 'остальной', 'состояние', 'экран', 'лондон', 'угодно', 'дабстеп', 'америка', 'ага', 'такой', 'потерять', 'просто', 'считаться', 'необычно', 'дикий', 'эстетика', 'происхождение', 'направление', 'степень', 'легкий', 'правильный', 'практически', 'манера', 'удар', 'реальный', 'реал', 'альбом', 'разговор', 'скрывать', 'удивительно', 'хит', 'настолько']

# %%
nature_ppmi = {}
for w, contexts in smoothppmi.items():
    nature_ppmi[w] = contexts['nature']
nature_top_fifty = sorted(nature_ppmi, key = nature_ppmi.get, reverse=True)[:200]
print(nature_top_fifty)
# Out:
# ['дерево', 'птица', 'ворона', 'сосна', 'лес', 'снег', 'синица', 'растение', 'сфоткать', 'небо', 'птичка', 'гриб', 'ствол', 'дятел', 'ветка', 'видео', 'фото', 'мышь', 'альбом', 'цветок', 'мороз', 'природа', 'цвести', 'осень', 'голос', 'куст', 'вблизи', 'хищник', 'ютуб', 'кормушка', 'след', 'воробей', 'ягода', 'лист', 'речка', 'заснимать', 'фоткать', 'лиса', 'тема', 'голубь', 'дуб', 'снимок', 'лесной', 'просека', 'провод', 'фотка', 'бежать', 'весна', 'листва', 'птенец', 'болото', 'детство', 'гроза', 'падать', 'наступать', 'желтый', 'крыса', 'локи', 'облако', 'комар', 'костер', 'сад', 'гнездо', 'цветочек', 'осенний', 'трава', 'похоже', 'елка', 'соленый', 'живой', 'дробь', 'животное', 'бегать', 'петь', 'расти', 'крик', 'лэп', 'видеть', 'пушистый', 'огород', 'свиристель', 'наблюдать', 'такой', 'соня', 'белок', 'туча', 'помнить', 'вживый', 'среда', 'рябина', 'семя', 'поле', 'кошка', 'вчера', 'берег', 'парк', 'картинка', 'кадр', 'лось', 'деревце', 'песенка', 'сухой', 'видно', 'хвост', 'пища', 'мертвый', 'залетать', 'собирать', 'телефон', 'семечко', 'ворон', 'змея', 'ссылка', 'сегодня', 'весенний', 'выглядеть', 'утка', 'человеческий', 'наверно', 'охота', 'фотик', 'редко', 'слышать', 'попадаться', 'метр', 'белый', 'услышать', 'холм', 'жаль', 'красавец', 'кот', 'посадить', 'вокруг', 'упасть', 'качество', 'кстати', 'охотиться', 'дорога', 'городской', 'окно', 'таскать', 'столб', 'камера', 'водиться', 'скоро', 'купаться', 'замечать', 'кажется', 'встречаться', 'зимний', 'холод', 'стая', 'вспомнить', 'организм', 'пышный', 'вложение', 'туман', 'бросаться', 'оказываться', 'ледяной', 'жук', 'какой', 'появляться', 'добавлять', 'снимать', 'часто', 'снежный', 'существо', 'поймать', 'прямо', 'жуть', 'близко', 'ручей', 'фотограф', 'трудно', 'поход', 'пространство', 'уметь', 'сверху', 'зеленый', 'зверь', 'видный', 'лишь', 'покой', 'нежный', 'солнечный', 'ролик', 'вон', 'страх', 'земля', 'занести', 'португалия', 'впервые', 'старый', 'замерзать', 'декоративный', 'дача', 'одинокий', 'темно', 'однако']

# %%
travel_ppmi = {}
for w, contexts in smoothppmi.items():
    travel_ppmi[w] = contexts['travel']
travel_top_fifty = sorted(travel_ppmi, key = travel_ppmi.get, reverse=True)[:200]
print(travel_top_fifty)
# Out:
# ['туда', 'день', 'другой', 'поездка', 'думать', 'самолет', 'лондон', 'дорога', 'какой', 'кто', 'такой', 'делать', 'дорого', 'включать', 'сам', 'наверное', 'второй', 'просто', 'выходить', 'рим', 'находиться', 'видеть', 'сколько', 'возможность', 'месяц', 'план', 'столица', 'побережье', 'посмотреть', 'улица', 'взять', 'магазин', 'прямо', 'счет', 'говорить', 'уходить', 'крым', 'проводить', 'старый', 'толпа', 'восторг', 'фотка', 'успевать', 'отличный', 'знакомый', 'е', 'сервис', 'спасибо', 'далеко', 'хотеться', 'метро', 'вопрос', 'считать', 'тема', 'работать', 'минимум', 'время', 'такси', 'берег', 'кажется', 'музей', 'отдыхать', 'англия', 'страна', 'франция', 'наш', 'приходиться', 'территория', 'п', 'куба', 'хватить', 'замок', 'обычный', 'достопримечательность', 'подумать', 'кофе', 'лишь', 'предел', 'дикий', 'это', 'д', 'слышать', 'порядок', 'попробовать', 'ходить', 'скоро', 'сочи', 'выкладывать', 'кстати', 'иметь', 'бассейн', 'вариант', 'недалеко', 'квартира', 'пора', 'раз', 'пока', 'дом', 'подходить', 'вкусный', 'отсутствие', 'путешествие', 'вещь', 'надеяться', 'представлять', 'знать', 'часть', 'спать', 'совершенно', 'весь', 'везде', 'ездить', 'настоящий', 'третий', 'один', 'сдавать', 'америка', 'небольшой', 'действительно', 'паспорт', 'азия', 'теплый', 'оказываться', 'приятно', 'погода', 'сила', 'замечать', 'курорт', 'желание', 'узнавать', 'практически', 'снег', 'ужас', 'место', 'завтрак', 'этот', 'душа', 'х', 'погулять', 'парк', 'центр', 'дорогой', 'понравиться', 'италия', 'рядом', 'клуб', 'проблема', 'уезжать', 'въезд', 'бояться', 'парень', 'мера', 'бронировать', 'согласный', 'единственный', 'целое', 'сильно', 'писать', 'направление', 'поэтому', 'стоять', 'остальной', 'простой', 'ток', 'слушать', 'отличие', 'язык', 'близкий', 'сказать', 'однако', 'европа', 'человек', 'откуда', 'конец', 'слишком', 'кафешок', 'полный', 'отправляться', 'таки', 'вести', 'настолько', 'отмечать', 'удаваться', 'курортный', 'крайний', 'остальное', 'друг', 'условие', 'узкий', 'известный', 'точка', 'мост', 'советовать', 'уровень', 'например', 'выбор', 'сожаление', 'муж', 'он', 'приезжать']

# %%
topfifty = {}

# %%
for i in categs:
    topfifty[i] = eval(i + '_top_fifty')

# %%
with open('top_twohundred_ppmi.pkl', 'wb') as tp:
    pkl.dump(topfifty, tp)
tp.close()

# %%
with open('')
